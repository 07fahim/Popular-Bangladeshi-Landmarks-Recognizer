# %%
# !pip install ddgs fastai tqdm --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 67.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 65.6 MB/s eta 0:00:00

# %%
import os
from pathlib import Path
from ddgs import DDGS
from tqdm.notebook import tqdm
from fastai.vision.utils import download_images, verify_images

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/MasterCourse/Bangladeshi_Landmarks
# Out:
# /content/drive/MyDrive/MasterCourse/Bangladeshi_Landmarks

# %%
DEST_ROOT = Path("dataset_places")
DEST_ROOT.mkdir(parents=True, exist_ok=True)

TARGET_PER_CLASS = 500
OVERFETCH_FACTOR = 2
MAX_RETRIES =10

ARCH_HINT = (
    "exterior architecture building monument facade heritage "
    "-interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding"
)
NATURE_HINT = (
    "landscape scenery nature hills forest river mountain valley beach waterfall "
    "-selfie -people -tourist -crowd -group -human -face -portrait"
)

places = [
    "Jatiya Sangsad Bhaban (Dhaka) Architecture only",
    "Ahsan Manzil (Dhaka) Architecture only",
    "Lalbagh Fort (Dhaka) Architecture only",
    "Dhaka Shaheed Minar (Bangladesh) Architecture only",
    "Sixty Dome Mosque (Bagerhat) Architecture only",
    "Somapura Mahavihara (Paharpur, Naogaon) Architecture only",
    "Kantajew Temple (Dinajpur) Architecture only",
    "Panam Nagar (Sonargaon, Narayanganj) Architecture only",
    "Tajhat Palace (Rangpur) Architecture only",
    "Cox’s Bazar Sea Beach (Cox’s Bazar) Nature only",
    "St. Martin's Island (Teknaf, Chhera Dwip) Nature only",
    "Sundarbans Mangrove Forest (Khulna) Nature onlye",
    "Jaflong (Sylhet) Nature only",
    "Ratargul Swamp Forest (Sylhet) Nature only",
    "Sajek Valley (Rangamati) Nature only",
    "Nafakhum Waterfall (Bandarban) Nature only"
]

# %%
def split_name_and_type(item: str):
    if "Architecture" in item:
        return item.replace(" Architecture only", "").strip(), "Architecture"
    elif "Nature" in item:
        return item.replace(" Nature only", "").strip(), "Nature"
    return item, "Unknown"

def build_query(place_name: str, kind: str, attempt: int) -> str:
    if kind == "Architecture":
        base = f"{place_name} {ARCH_HINT}"
    elif kind == "Nature":
        base = f"{place_name} {NATURE_HINT}"
    else:
        base = place_name
    if attempt > 0:
        base += f" photo view picture {attempt}"
    return base

def duckduckgo_search(query: str, needed: int):
    urls, seen = [], set()
    try:
        with DDGS() as ddgs:
            for r in ddgs.images(query, safesearch="on", type_image="photo", max_results=needed*2):
                url = r.get("image")
                if not url or url in seen:
                    continue
                if any(bad in url.lower() for bad in ["svg", "base64,", "data:image"]):
                    continue
                seen.add(url)
                urls.append(url)
                if len(urls) >= needed:
                    break
    except Exception as e:
        print(f"[!] DuckDuckGo search failed: {e}")
    return urls

def sanitize_dirname(name: str) -> str:
    return "".join(c for c in name if c.isalnum() or c in " -_()&',.").strip()

def ensure_target_count(folder: Path) -> int:
    exts = {".jpg", ".jpeg", ".png", ".bmp", ".gif", ".webp"}
    return sum(1 for p in folder.glob("*") if p.suffix.lower() in exts)

# %%
summary = []

for item in places:
    place_name, kind = split_name_and_type(item)
    class_dir = DEST_ROOT / sanitize_dirname(place_name)
    class_dir.mkdir(parents=True, exist_ok=True)

    for attempt in range(MAX_RETRIES):
        have = ensure_target_count(class_dir)
        if have >= TARGET_PER_CLASS:
            print(f"[✓] {place_name}: reached {have}/{TARGET_PER_CLASS} images.")
            break

        need = TARGET_PER_CLASS - have
        urls_needed = int(need * OVERFETCH_FACTOR)
        query = build_query(place_name, kind, attempt)

        print(f"\n=== {place_name} ({kind}) | Attempt {attempt+1} ===")
        print(f"Query: {query}")
        print(f"Need {need} more images (fetching {urls_needed} URLs).")

        urls = duckduckgo_search(query, urls_needed)
        if not urls:
            print(f"[!] No URLs found this attempt.")
            continue

        urls_file = class_dir / f"_urls_attempt{attempt+1}.txt"
        urls_file.write_text("\n".join(urls), encoding="utf-8")
        urls_list = urls_file.read_text().splitlines()
        download_images(str(class_dir), urls=urls_list, preserve_filename=False, timeout=30, n_workers=8)
        failed = verify_images(str(class_dir))
        if failed:
            print(f"Removed {len(failed)} corrupt images.")

        final_count = ensure_target_count(class_dir)
        print(f"[i] {place_name}: now {final_count}/{TARGET_PER_CLASS} images.")

    final_count = ensure_target_count(class_dir)
    status = "OK" if final_count >= TARGET_PER_CLASS else "SHORT"
    summary.append((place_name, kind, final_count, status))
# Out:
# === Jatiya Sangsad Bhaban (Dhaka) (Architecture) | Attempt 1 ===
# Query: Jatiya Sangsad Bhaban (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding
# Need 500 more images (fetching 1000 URLs).
# Removed 44 corrupt images.
# [i] Jatiya Sangsad Bhaban (Dhaka): now 84/500 images.
#
# === Jatiya Sangsad Bhaban (Dhaka) (Architecture) | Attempt 2 ===
# Query: Jatiya Sangsad Bhaban (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 1
# Need 416 more images (fetching 832 URLs).
# Removed 44 corrupt images.
# [i] Jatiya Sangsad Bhaban (Dhaka): now 171/500 images.
#
# === Jatiya Sangsad Bhaban (Dhaka) (Architecture) | Attempt 3 ===
# Query: Jatiya Sangsad Bhaban (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 2
# Need 329 more images (fetching 658 URLs).
# Removed 44 corrupt images.
# [i] Jatiya Sangsad Bhaban (Dhaka): now 258/500 images.
#
# === Jatiya Sangsad Bhaban (Dhaka) (Architecture) | Attempt 4 ===
# Query: Jatiya Sangsad Bhaban (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 3
# Need 242 more images (fetching 484 URLs).
# Removed 44 corrupt images.
# [i] Jatiya Sangsad Bhaban (Dhaka): now 344/500 images.
#
# === Jatiya Sangsad Bhaban (Dhaka) (Architecture) | Attempt 5 ===
# Query: Jatiya Sangsad Bhaban (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 4
# Need 156 more images (fetching 312 URLs).
# Removed 44 corrupt images.
# [i] Jatiya Sangsad Bhaban (Dhaka): now 432/500 images.
#
# === Jatiya Sangsad Bhaban (Dhaka) (Architecture) | Attempt 6 ===
# Query: Jatiya Sangsad Bhaban (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 5
# Need 68 more images (fetching 136 URLs).
# Removed 44 corrupt images.
# [i] Jatiya Sangsad Bhaban (Dhaka): now 520/500 images.
# [✓] Jatiya Sangsad Bhaban (Dhaka): reached 520/500 images.
#
# === Ahsan Manzil (Dhaka) (Architecture) | Attempt 1 ===
# Query: Ahsan Manzil (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding
# Need 500 more images (fetching 1000 URLs).
# Removed 35 corrupt images.
# [i] Ahsan Manzil (Dhaka): now 96/500 images.
#
# === Ahsan Manzil (Dhaka) (Architecture) | Attempt 2 ===
# Query: Ahsan Manzil (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 1
# Need 404 more images (fetching 808 URLs).
# Removed 35 corrupt images.
# [i] Ahsan Manzil (Dhaka): now 191/500 images.
#
# === Ahsan Manzil (Dhaka) (Architecture) | Attempt 3 ===
# Query: Ahsan Manzil (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 2
# Need 309 more images (fetching 618 URLs).
# Removed 35 corrupt images.
# [i] Ahsan Manzil (Dhaka): now 287/500 images.
#
# === Ahsan Manzil (Dhaka) (Architecture) | Attempt 4 ===
# Query: Ahsan Manzil (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 3
# Need 213 more images (fetching 426 URLs).
# Removed 35 corrupt images.
# [i] Ahsan Manzil (Dhaka): now 383/500 images.
#
# === Ahsan Manzil (Dhaka) (Architecture) | Attempt 5 ===
# Query: Ahsan Manzil (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 4
# Need 117 more images (fetching 234 URLs).
# Removed 35 corrupt images.
# [i] Ahsan Manzil (Dhaka): now 478/500 images.
#
# === Ahsan Manzil (Dhaka) (Architecture) | Attempt 6 ===
# Query: Ahsan Manzil (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 5
# Need 22 more images (fetching 44 URLs).
# Removed 35 corrupt images.
# [i] Ahsan Manzil (Dhaka): now 520/500 images.
# [✓] Ahsan Manzil (Dhaka): reached 520/500 images.
#
# === Lalbagh Fort (Dhaka) (Architecture) | Attempt 1 ===
# Query: Lalbagh Fort (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding
# Need 500 more images (fetching 1000 URLs).
# Removed 35 corrupt images.
# [i] Lalbagh Fort (Dhaka): now 88/500 images.
#
# === Lalbagh Fort (Dhaka) (Architecture) | Attempt 2 ===
# Query: Lalbagh Fort (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 1
# Need 412 more images (fetching 824 URLs).
# Removed 35 corrupt images.
# [i] Lalbagh Fort (Dhaka): now 177/500 images.
#
# === Lalbagh Fort (Dhaka) (Architecture) | Attempt 3 ===
# Query: Lalbagh Fort (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 2
# Need 323 more images (fetching 646 URLs).
# Removed 35 corrupt images.
# [i] Lalbagh Fort (Dhaka): now 263/500 images.
#
# === Lalbagh Fort (Dhaka) (Architecture) | Attempt 4 ===
# Query: Lalbagh Fort (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 3
# Need 237 more images (fetching 474 URLs).
# Removed 35 corrupt images.
# [i] Lalbagh Fort (Dhaka): now 351/500 images.
#
# === Lalbagh Fort (Dhaka) (Architecture) | Attempt 5 ===
# Query: Lalbagh Fort (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 4
# Need 149 more images (fetching 298 URLs).
# Removed 35 corrupt images.
# [i] Lalbagh Fort (Dhaka): now 438/500 images.
#
# === Lalbagh Fort (Dhaka) (Architecture) | Attempt 6 ===
# Query: Lalbagh Fort (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 5
# Need 62 more images (fetching 124 URLs).
# Removed 35 corrupt images.
# [i] Lalbagh Fort (Dhaka): now 524/500 images.
# [✓] Lalbagh Fort (Dhaka): reached 524/500 images.
#
# === Dhaka Shaheed Minar (Bangladesh) (Architecture) | Attempt 1 ===
# Query: Dhaka Shaheed Minar (Bangladesh) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding
# Need 500 more images (fetching 1000 URLs).
# Removed 47 corrupt images.
# [i] Dhaka Shaheed Minar (Bangladesh): now 88/500 images.
#
# === Dhaka Shaheed Minar (Bangladesh) (Architecture) | Attempt 2 ===
# Query: Dhaka Shaheed Minar (Bangladesh) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 1
# Need 412 more images (fetching 824 URLs).
# Removed 47 corrupt images.
# [i] Dhaka Shaheed Minar (Bangladesh): now 178/500 images.
#
# === Dhaka Shaheed Minar (Bangladesh) (Architecture) | Attempt 3 ===
# Query: Dhaka Shaheed Minar (Bangladesh) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 2
# Need 322 more images (fetching 644 URLs).
# Removed 47 corrupt images.
# [i] Dhaka Shaheed Minar (Bangladesh): now 268/500 images.
#
# === Dhaka Shaheed Minar (Bangladesh) (Architecture) | Attempt 4 ===
# Query: Dhaka Shaheed Minar (Bangladesh) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 3
# Need 232 more images (fetching 464 URLs).
# Removed 47 corrupt images.
# [i] Dhaka Shaheed Minar (Bangladesh): now 359/500 images.
#
# === Dhaka Shaheed Minar (Bangladesh) (Architecture) | Attempt 5 ===
# Query: Dhaka Shaheed Minar (Bangladesh) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 4
# Need 141 more images (fetching 282 URLs).
# Removed 47 corrupt images.
# [i] Dhaka Shaheed Minar (Bangladesh): now 448/500 images.
#
# === Dhaka Shaheed Minar (Bangladesh) (Architecture) | Attempt 6 ===
# Query: Dhaka Shaheed Minar (Bangladesh) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 5
# Need 52 more images (fetching 104 URLs).
# Removed 47 corrupt images.
# [i] Dhaka Shaheed Minar (Bangladesh): now 538/500 images.
# [✓] Dhaka Shaheed Minar (Bangladesh): reached 538/500 images.
#
# === Sixty Dome Mosque (Bagerhat) (Architecture) | Attempt 1 ===
# Query: Sixty Dome Mosque (Bagerhat) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding
# Need 500 more images (fetching 1000 URLs).
# Removed 43 corrupt images.
# [i] Sixty Dome Mosque (Bagerhat): now 91/500 images.
#
# === Sixty Dome Mosque (Bagerhat) (Architecture) | Attempt 2 ===
# Query: Sixty Dome Mosque (Bagerhat) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 1
# Need 409 more images (fetching 818 URLs).
# Removed 43 corrupt images.
# [i] Sixty Dome Mosque (Bagerhat): now 181/500 images.
#
# === Sixty Dome Mosque (Bagerhat) (Architecture) | Attempt 3 ===
# Query: Sixty Dome Mosque (Bagerhat) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 2
# Need 319 more images (fetching 638 URLs).
# Removed 43 corrupt images.
# [i] Sixty Dome Mosque (Bagerhat): now 273/500 images.
#
# === Sixty Dome Mosque (Bagerhat) (Architecture) | Attempt 4 ===
# Query: Sixty Dome Mosque (Bagerhat) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 3
# Need 227 more images (fetching 454 URLs).
# Removed 43 corrupt images.
# [i] Sixty Dome Mosque (Bagerhat): now 365/500 images.
#
# === Sixty Dome Mosque (Bagerhat) (Architecture) | Attempt 5 ===
# Query: Sixty Dome Mosque (Bagerhat) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 4
# Need 135 more images (fetching 270 URLs).
# Removed 43 corrupt images.
# [i] Sixty Dome Mosque (Bagerhat): now 458/500 images.
#
# === Sixty Dome Mosque (Bagerhat) (Architecture) | Attempt 6 ===
# Query: Sixty Dome Mosque (Bagerhat) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 5
# Need 42 more images (fetching 84 URLs).
# Removed 43 corrupt images.
# [i] Sixty Dome Mosque (Bagerhat): now 537/500 images.
# [✓] Sixty Dome Mosque (Bagerhat): reached 537/500 images.
#
# === Somapura Mahavihara (Paharpur, Naogaon) (Architecture) | Attempt 1 ===
# Query: Somapura Mahavihara (Paharpur, Naogaon) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding
# Need 500 more images (fetching 1000 URLs).
# Removed 54 corrupt images.
# [i] Somapura Mahavihara (Paharpur, Naogaon): now 97/500 images.
#
# === Somapura Mahavihara (Paharpur, Naogaon) (Architecture) | Attempt 2 ===
# Query: Somapura Mahavihara (Paharpur, Naogaon) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 1
# Need 403 more images (fetching 806 URLs).
# Removed 54 corrupt images.
# [i] Somapura Mahavihara (Paharpur, Naogaon): now 193/500 images.
#
# === Somapura Mahavihara (Paharpur, Naogaon) (Architecture) | Attempt 3 ===
# Query: Somapura Mahavihara (Paharpur, Naogaon) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 2
# Need 307 more images (fetching 614 URLs).
# Removed 54 corrupt images.
# [i] Somapura Mahavihara (Paharpur, Naogaon): now 288/500 images.
#
# === Somapura Mahavihara (Paharpur, Naogaon) (Architecture) | Attempt 4 ===
# Query: Somapura Mahavihara (Paharpur, Naogaon) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 3
# Need 212 more images (fetching 424 URLs).
# Removed 54 corrupt images.
# [i] Somapura Mahavihara (Paharpur, Naogaon): now 385/500 images.
#
# === Somapura Mahavihara (Paharpur, Naogaon) (Architecture) | Attempt 5 ===
# Query: Somapura Mahavihara (Paharpur, Naogaon) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 4
# Need 115 more images (fetching 230 URLs).
# Removed 54 corrupt images.
# [i] Somapura Mahavihara (Paharpur, Naogaon): now 480/500 images.
#
# === Somapura Mahavihara (Paharpur, Naogaon) (Architecture) | Attempt 6 ===
# Query: Somapura Mahavihara (Paharpur, Naogaon) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 5
# Need 20 more images (fetching 40 URLs).
# Removed 54 corrupt images.
# [i] Somapura Mahavihara (Paharpur, Naogaon): now 519/500 images.
# [✓] Somapura Mahavihara (Paharpur, Naogaon): reached 519/500 images.
#
# === Kantajew Temple (Dinajpur) (Architecture) | Attempt 1 ===
# Query: Kantajew Temple (Dinajpur) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding
# Need 500 more images (fetching 1000 URLs).
# Removed 41 corrupt images.
# [i] Kantajew Temple (Dinajpur): now 83/500 images.
#
# === Kantajew Temple (Dinajpur) (Architecture) | Attempt 2 ===
# Query: Kantajew Temple (Dinajpur) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 1
# Need 417 more images (fetching 834 URLs).
# Removed 41 corrupt images.
# [i] Kantajew Temple (Dinajpur): now 165/500 images.
#
# === Kantajew Temple (Dinajpur) (Architecture) | Attempt 3 ===
# Query: Kantajew Temple (Dinajpur) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 2
# Need 335 more images (fetching 670 URLs).
# Removed 41 corrupt images.
# [i] Kantajew Temple (Dinajpur): now 242/500 images.
#
# === Kantajew Temple (Dinajpur) (Architecture) | Attempt 4 ===
# Query: Kantajew Temple (Dinajpur) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 3
# Need 258 more images (fetching 516 URLs).
# Removed 41 corrupt images.
# [i] Kantajew Temple (Dinajpur): now 322/500 images.
#
# === Kantajew Temple (Dinajpur) (Architecture) | Attempt 5 ===
# Query: Kantajew Temple (Dinajpur) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 4
# Need 178 more images (fetching 356 URLs).
# Removed 41 corrupt images.
# [i] Kantajew Temple (Dinajpur): now 405/500 images.
#
# === Kantajew Temple (Dinajpur) (Architecture) | Attempt 6 ===
# Query: Kantajew Temple (Dinajpur) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 5
# Need 95 more images (fetching 190 URLs).
# Removed 41 corrupt images.
# [i] Kantajew Temple (Dinajpur): now 488/500 images.
#
# === Kantajew Temple (Dinajpur) (Architecture) | Attempt 7 ===
# Query: Kantajew Temple (Dinajpur) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 6
# Need 12 more images (fetching 24 URLs).
# Removed 41 corrupt images.
# [i] Kantajew Temple (Dinajpur): now 508/500 images.
# [✓] Kantajew Temple (Dinajpur): reached 508/500 images.
#
# === Panam Nagar (Sonargaon, Narayanganj) (Architecture) | Attempt 1 ===
# Query: Panam Nagar (Sonargaon, Narayanganj) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding
# Need 500 more images (fetching 1000 URLs).
# Removed 51 corrupt images.
# [i] Panam Nagar (Sonargaon, Narayanganj): now 93/500 images.
#
# === Panam Nagar (Sonargaon, Narayanganj) (Architecture) | Attempt 2 ===
# Query: Panam Nagar (Sonargaon, Narayanganj) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 1
# Need 407 more images (fetching 814 URLs).
# Removed 51 corrupt images.
# [i] Panam Nagar (Sonargaon, Narayanganj): now 185/500 images.
#
# === Panam Nagar (Sonargaon, Narayanganj) (Architecture) | Attempt 3 ===
# Query: Panam Nagar (Sonargaon, Narayanganj) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 2
# Need 315 more images (fetching 630 URLs).
# Removed 51 corrupt images.
# [i] Panam Nagar (Sonargaon, Narayanganj): now 277/500 images.
#
# === Panam Nagar (Sonargaon, Narayanganj) (Architecture) | Attempt 4 ===
# Query: Panam Nagar (Sonargaon, Narayanganj) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 3
# Need 223 more images (fetching 446 URLs).
# Removed 51 corrupt images.
# [i] Panam Nagar (Sonargaon, Narayanganj): now 371/500 images.
#
# === Panam Nagar (Sonargaon, Narayanganj) (Architecture) | Attempt 5 ===
# Query: Panam Nagar (Sonargaon, Narayanganj) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 4
# Need 129 more images (fetching 258 URLs).
# Removed 51 corrupt images.
# [i] Panam Nagar (Sonargaon, Narayanganj): now 462/500 images.
#
# === Panam Nagar (Sonargaon, Narayanganj) (Architecture) | Attempt 6 ===
# Query: Panam Nagar (Sonargaon, Narayanganj) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 5
# Need 38 more images (fetching 76 URLs).
# Removed 51 corrupt images.
# [i] Panam Nagar (Sonargaon, Narayanganj): now 531/500 images.
# [✓] Panam Nagar (Sonargaon, Narayanganj): reached 531/500 images.
#
# === Tajhat Palace (Rangpur) (Architecture) | Attempt 1 ===
# Query: Tajhat Palace (Rangpur) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding
# Need 500 more images (fetching 1000 URLs).
# Removed 38 corrupt images.
# [i] Tajhat Palace (Rangpur): now 82/500 images.
#
# === Tajhat Palace (Rangpur) (Architecture) | Attempt 2 ===
# Query: Tajhat Palace (Rangpur) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 1
# Need 418 more images (fetching 836 URLs).
# Removed 38 corrupt images.
# [i] Tajhat Palace (Rangpur): now 165/500 images.
#
# === Tajhat Palace (Rangpur) (Architecture) | Attempt 3 ===
# Query: Tajhat Palace (Rangpur) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 2
# Need 335 more images (fetching 670 URLs).
# Removed 38 corrupt images.
# [i] Tajhat Palace (Rangpur): now 247/500 images.
#
# === Tajhat Palace (Rangpur) (Architecture) | Attempt 4 ===
# Query: Tajhat Palace (Rangpur) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 3
# Need 253 more images (fetching 506 URLs).
# Removed 38 corrupt images.
# [i] Tajhat Palace (Rangpur): now 329/500 images.
#
# === Tajhat Palace (Rangpur) (Architecture) | Attempt 5 ===
# Query: Tajhat Palace (Rangpur) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 4
# Need 171 more images (fetching 342 URLs).
# Removed 38 corrupt images.
# [i] Tajhat Palace (Rangpur): now 412/500 images.
#
# === Tajhat Palace (Rangpur) (Architecture) | Attempt 6 ===
# Query: Tajhat Palace (Rangpur) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 5
# Need 88 more images (fetching 176 URLs).
# Removed 38 corrupt images.
# [i] Tajhat Palace (Rangpur): now 496/500 images.
#
# === Tajhat Palace (Rangpur) (Architecture) | Attempt 7 ===
# Query: Tajhat Palace (Rangpur) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 6
# Need 4 more images (fetching 8 URLs).
# Removed 38 corrupt images.
# [i] Tajhat Palace (Rangpur): now 502/500 images.
# [✓] Tajhat Palace (Rangpur): reached 502/500 images.
#
# === Cox’s Bazar Sea Beach (Cox’s Bazar) (Nature) | Attempt 1 ===
# Query: Cox’s Bazar Sea Beach (Cox’s Bazar) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait
# Need 500 more images (fetching 1000 URLs).
# Removed 48 corrupt images.
# [i] Cox’s Bazar Sea Beach (Cox’s Bazar): now 92/500 images.
#
# === Cox’s Bazar Sea Beach (Cox’s Bazar) (Nature) | Attempt 2 ===
# Query: Cox’s Bazar Sea Beach (Cox’s Bazar) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 1
# Need 408 more images (fetching 816 URLs).
# Removed 48 corrupt images.
# [i] Cox’s Bazar Sea Beach (Cox’s Bazar): now 185/500 images.
#
# === Cox’s Bazar Sea Beach (Cox’s Bazar) (Nature) | Attempt 3 ===
# Query: Cox’s Bazar Sea Beach (Cox’s Bazar) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 2
# Need 315 more images (fetching 630 URLs).
# Removed 48 corrupt images.
# [i] Cox’s Bazar Sea Beach (Cox’s Bazar): now 279/500 images.
#
# === Cox’s Bazar Sea Beach (Cox’s Bazar) (Nature) | Attempt 4 ===
# Query: Cox’s Bazar Sea Beach (Cox’s Bazar) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 3
# Need 221 more images (fetching 442 URLs).
# Removed 48 corrupt images.
# [i] Cox’s Bazar Sea Beach (Cox’s Bazar): now 372/500 images.
#
# === Cox’s Bazar Sea Beach (Cox’s Bazar) (Nature) | Attempt 5 ===
# Query: Cox’s Bazar Sea Beach (Cox’s Bazar) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 4
# Need 128 more images (fetching 256 URLs).
# Removed 48 corrupt images.
# [i] Cox’s Bazar Sea Beach (Cox’s Bazar): now 465/500 images.
#
# === Cox’s Bazar Sea Beach (Cox’s Bazar) (Nature) | Attempt 6 ===
# Query: Cox’s Bazar Sea Beach (Cox’s Bazar) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 5
# Need 35 more images (fetching 70 URLs).
# Removed 48 corrupt images.
# [i] Cox’s Bazar Sea Beach (Cox’s Bazar): now 530/500 images.
# [✓] Cox’s Bazar Sea Beach (Cox’s Bazar): reached 530/500 images.
#
# === St. Martin's Island (Teknaf, Chhera Dwip) (Nature) | Attempt 1 ===
# Query: St. Martin's Island (Teknaf, Chhera Dwip) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait
# Need 500 more images (fetching 1000 URLs).
# Removed 56 corrupt images.
# [i] St. Martin's Island (Teknaf, Chhera Dwip): now 86/500 images.
#
# === St. Martin's Island (Teknaf, Chhera Dwip) (Nature) | Attempt 2 ===
# Query: St. Martin's Island (Teknaf, Chhera Dwip) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 1
# Need 414 more images (fetching 828 URLs).
# Removed 56 corrupt images.
# [i] St. Martin's Island (Teknaf, Chhera Dwip): now 170/500 images.
#
# === St. Martin's Island (Teknaf, Chhera Dwip) (Nature) | Attempt 3 ===
# Query: St. Martin's Island (Teknaf, Chhera Dwip) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 2
# Need 330 more images (fetching 660 URLs).
# Removed 56 corrupt images.
# [i] St. Martin's Island (Teknaf, Chhera Dwip): now 255/500 images.
#
# === St. Martin's Island (Teknaf, Chhera Dwip) (Nature) | Attempt 4 ===
# Query: St. Martin's Island (Teknaf, Chhera Dwip) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 3
# Need 245 more images (fetching 490 URLs).
# Removed 56 corrupt images.
# [i] St. Martin's Island (Teknaf, Chhera Dwip): now 340/500 images.
#
# === St. Martin's Island (Teknaf, Chhera Dwip) (Nature) | Attempt 5 ===
# Query: St. Martin's Island (Teknaf, Chhera Dwip) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 4
# Need 160 more images (fetching 320 URLs).
# Removed 56 corrupt images.
# [i] St. Martin's Island (Teknaf, Chhera Dwip): now 425/500 images.
#
# === St. Martin's Island (Teknaf, Chhera Dwip) (Nature) | Attempt 6 ===
# Query: St. Martin's Island (Teknaf, Chhera Dwip) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 5
# Need 75 more images (fetching 150 URLs).
# Removed 56 corrupt images.
# [i] St. Martin's Island (Teknaf, Chhera Dwip): now 508/500 images.
# [✓] St. Martin's Island (Teknaf, Chhera Dwip): reached 508/500 images.
#
# === Sundarbans Mangrove Forest (Khulna)e (Nature) | Attempt 1 ===
# Query: Sundarbans Mangrove Forest (Khulna)e landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait
# Need 500 more images (fetching 1000 URLs).
# Removed 51 corrupt images.
# [i] Sundarbans Mangrove Forest (Khulna)e: now 93/500 images.
#
# === Sundarbans Mangrove Forest (Khulna)e (Nature) | Attempt 2 ===
# Query: Sundarbans Mangrove Forest (Khulna)e landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 1
# Need 407 more images (fetching 814 URLs).
# Removed 51 corrupt images.
# [i] Sundarbans Mangrove Forest (Khulna)e: now 185/500 images.
#
# === Sundarbans Mangrove Forest (Khulna)e (Nature) | Attempt 3 ===
# Query: Sundarbans Mangrove Forest (Khulna)e landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 2
# Need 315 more images (fetching 630 URLs).
# Removed 51 corrupt images.
# [i] Sundarbans Mangrove Forest (Khulna)e: now 276/500 images.
#
# === Sundarbans Mangrove Forest (Khulna)e (Nature) | Attempt 4 ===
# Query: Sundarbans Mangrove Forest (Khulna)e landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 3
# Need 224 more images (fetching 448 URLs).
# Removed 51 corrupt images.
# [i] Sundarbans Mangrove Forest (Khulna)e: now 368/500 images.
#
# === Sundarbans Mangrove Forest (Khulna)e (Nature) | Attempt 5 ===
# Query: Sundarbans Mangrove Forest (Khulna)e landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 4
# Need 132 more images (fetching 264 URLs).
# Removed 51 corrupt images.
# [i] Sundarbans Mangrove Forest (Khulna)e: now 462/500 images.
#
# === Sundarbans Mangrove Forest (Khulna)e (Nature) | Attempt 6 ===
# Query: Sundarbans Mangrove Forest (Khulna)e landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 5
# Need 38 more images (fetching 76 URLs).
# Removed 51 corrupt images.
# [i] Sundarbans Mangrove Forest (Khulna)e: now 531/500 images.
# [✓] Sundarbans Mangrove Forest (Khulna)e: reached 531/500 images.
#
# === Jaflong (Sylhet) (Nature) | Attempt 1 ===
# Query: Jaflong (Sylhet) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait
# Need 500 more images (fetching 1000 URLs).
# Removed 31 corrupt images.
# [i] Jaflong (Sylhet): now 92/500 images.
#
# === Jaflong (Sylhet) (Nature) | Attempt 2 ===
# Query: Jaflong (Sylhet) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 1
# Need 408 more images (fetching 816 URLs).
# Removed 31 corrupt images.
# [i] Jaflong (Sylhet): now 184/500 images.
#
# === Jaflong (Sylhet) (Nature) | Attempt 3 ===
# Query: Jaflong (Sylhet) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 2
# Need 316 more images (fetching 632 URLs).
# Removed 31 corrupt images.
# [i] Jaflong (Sylhet): now 279/500 images.
#
# === Jaflong (Sylhet) (Nature) | Attempt 4 ===
# Query: Jaflong (Sylhet) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 3
# Need 221 more images (fetching 442 URLs).
# Removed 31 corrupt images.
# [i] Jaflong (Sylhet): now 372/500 images.
#
# === Jaflong (Sylhet) (Nature) | Attempt 5 ===
# Query: Jaflong (Sylhet) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 4
# Need 128 more images (fetching 256 URLs).
# Removed 31 corrupt images.
# [i] Jaflong (Sylhet): now 465/500 images.
#
# === Jaflong (Sylhet) (Nature) | Attempt 6 ===
# Query: Jaflong (Sylhet) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 5
# Need 35 more images (fetching 70 URLs).
# Removed 31 corrupt images.
# [i] Jaflong (Sylhet): now 531/500 images.
# [✓] Jaflong (Sylhet): reached 531/500 images.
#
# === Ratargul Swamp Forest (Sylhet) (Nature) | Attempt 1 ===
# Query: Ratargul Swamp Forest (Sylhet) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait
# Need 500 more images (fetching 1000 URLs).
# Removed 45 corrupt images.
# [i] Ratargul Swamp Forest (Sylhet): now 92/500 images.
#
# === Ratargul Swamp Forest (Sylhet) (Nature) | Attempt 2 ===
# Query: Ratargul Swamp Forest (Sylhet) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 1
# Need 408 more images (fetching 816 URLs).
# Removed 45 corrupt images.
# [i] Ratargul Swamp Forest (Sylhet): now 187/500 images.
#
# === Ratargul Swamp Forest (Sylhet) (Nature) | Attempt 3 ===
# Query: Ratargul Swamp Forest (Sylhet) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 2
# Need 313 more images (fetching 626 URLs).
# Removed 45 corrupt images.
# [i] Ratargul Swamp Forest (Sylhet): now 282/500 images.
#
# === Ratargul Swamp Forest (Sylhet) (Nature) | Attempt 4 ===
# Query: Ratargul Swamp Forest (Sylhet) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 3
# Need 218 more images (fetching 436 URLs).
# Removed 45 corrupt images.
# [i] Ratargul Swamp Forest (Sylhet): now 377/500 images.
#
# === Ratargul Swamp Forest (Sylhet) (Nature) | Attempt 5 ===
# Query: Ratargul Swamp Forest (Sylhet) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 4
# Need 123 more images (fetching 246 URLs).
# Removed 45 corrupt images.
# [i] Ratargul Swamp Forest (Sylhet): now 472/500 images.
#
# === Ratargul Swamp Forest (Sylhet) (Nature) | Attempt 6 ===
# Query: Ratargul Swamp Forest (Sylhet) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 5
# Need 28 more images (fetching 56 URLs).
# Removed 45 corrupt images.
# [i] Ratargul Swamp Forest (Sylhet): now 525/500 images.
# [✓] Ratargul Swamp Forest (Sylhet): reached 525/500 images.
#
# === Sajek Valley (Rangamati) (Nature) | Attempt 1 ===
# Query: Sajek Valley (Rangamati) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait
# Need 500 more images (fetching 1000 URLs).
# Removed 39 corrupt images.
# [i] Sajek Valley (Rangamati): now 92/500 images.
#
# === Sajek Valley (Rangamati) (Nature) | Attempt 2 ===
# Query: Sajek Valley (Rangamati) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 1
# Need 408 more images (fetching 816 URLs).
# Removed 39 corrupt images.
# [i] Sajek Valley (Rangamati): now 182/500 images.
#
# === Sajek Valley (Rangamati) (Nature) | Attempt 3 ===
# Query: Sajek Valley (Rangamati) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 2
# Need 318 more images (fetching 636 URLs).
# Removed 39 corrupt images.
# [i] Sajek Valley (Rangamati): now 272/500 images.
#
# === Sajek Valley (Rangamati) (Nature) | Attempt 4 ===
# Query: Sajek Valley (Rangamati) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 3
# Need 228 more images (fetching 456 URLs).
# Removed 39 corrupt images.
# [i] Sajek Valley (Rangamati): now 362/500 images.
#
# === Sajek Valley (Rangamati) (Nature) | Attempt 5 ===
# Query: Sajek Valley (Rangamati) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 4
# Need 138 more images (fetching 276 URLs).
# Removed 39 corrupt images.
# [i] Sajek Valley (Rangamati): now 452/500 images.
#
# === Sajek Valley (Rangamati) (Nature) | Attempt 6 ===
# Query: Sajek Valley (Rangamati) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 5
# Need 48 more images (fetching 96 URLs).
# Removed 39 corrupt images.
# [i] Sajek Valley (Rangamati): now 539/500 images.
# [✓] Sajek Valley (Rangamati): reached 539/500 images.
#
# === Nafakhum Waterfall (Bandarban) (Nature) | Attempt 1 ===
# Query: Nafakhum Waterfall (Bandarban) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait
# Need 500 more images (fetching 1000 URLs).
# Removed 45 corrupt images.
# [i] Nafakhum Waterfall (Bandarban): now 95/500 images.
#
# === Nafakhum Waterfall (Bandarban) (Nature) | Attempt 2 ===
# Query: Nafakhum Waterfall (Bandarban) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 1
# Need 405 more images (fetching 810 URLs).
# Removed 45 corrupt images.
# [i] Nafakhum Waterfall (Bandarban): now 189/500 images.
#
# === Nafakhum Waterfall (Bandarban) (Nature) | Attempt 3 ===
# Query: Nafakhum Waterfall (Bandarban) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 2
# Need 311 more images (fetching 622 URLs).
# Removed 45 corrupt images.
# [i] Nafakhum Waterfall (Bandarban): now 283/500 images.
#
# === Nafakhum Waterfall (Bandarban) (Nature) | Attempt 4 ===
# Query: Nafakhum Waterfall (Bandarban) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 3
# Need 217 more images (fetching 434 URLs).
# Removed 45 corrupt images.
# [i] Nafakhum Waterfall (Bandarban): now 376/500 images.
#
# === Nafakhum Waterfall (Bandarban) (Nature) | Attempt 5 ===
# Query: Nafakhum Waterfall (Bandarban) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 4
# Need 124 more images (fetching 248 URLs).
# Removed 45 corrupt images.
# [i] Nafakhum Waterfall (Bandarban): now 470/500 images.
#
# === Nafakhum Waterfall (Bandarban) (Nature) | Attempt 6 ===
# Query: Nafakhum Waterfall (Bandarban) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 5
# Need 30 more images (fetching 60 URLs).
# Removed 45 corrupt images.
# [i] Nafakhum Waterfall (Bandarban): now 526/500 images.
# [✓] Nafakhum Waterfall (Bandarban): reached 526/500 images.

# %%
from PIL import Image, UnidentifiedImageError
for img_path in DEST_ROOT.rglob("*"):
    if img_path.is_file() and not img_path.name.startswith("."):
        try:
            img = Image.open(img_path)
            img.verify()
        except (IOError, SyntaxError, UnidentifiedImageError):
            print(f"Removing corrupted image: {img_path}")
            img_path.unlink()  # delete corrupted image
# Out:
# Removing corrupted image: dataset_places/Jatiya Sangsad Bhaban (Dhaka)/_urls_attempt1.txt
# Removing corrupted image: dataset_places/Jatiya Sangsad Bhaban (Dhaka)/_urls_attempt2.txt
# Removing corrupted image: dataset_places/Jatiya Sangsad Bhaban (Dhaka)/_urls_attempt3.txt
# Removing corrupted image: dataset_places/Jatiya Sangsad Bhaban (Dhaka)/_urls_attempt4.txt
# Removing corrupted image: dataset_places/Jatiya Sangsad Bhaban (Dhaka)/_urls_attempt5.txt
# Removing corrupted image: dataset_places/Jatiya Sangsad Bhaban (Dhaka)/_urls_attempt6.txt
# Removing corrupted image: dataset_places/Ahsan Manzil (Dhaka)/_urls_attempt1.txt
# Removing corrupted image: dataset_places/Ahsan Manzil (Dhaka)/_urls_attempt2.txt
# Removing corrupted image: dataset_places/Ahsan Manzil (Dhaka)/_urls_attempt3.txt
# Removing corrupted image: dataset_places/Ahsan Manzil (Dhaka)/8d9629eb-93a7-41a8-97be-156585da6137.jpg
# Removing corrupted image: dataset_places/Ahsan Manzil (Dhaka)/_urls_attempt4.txt
# Removing corrupted image: dataset_places/Ahsan Manzil (Dhaka)/_urls_attempt5.txt
# Removing corrupted image: dataset_places/Ahsan Manzil (Dhaka)/_urls_attempt6.txt
# Removing corrupted image: dataset_places/Lalbagh Fort (Dhaka)/_urls_attempt1.txt
# Removing corrupted image: dataset_places/Lalbagh Fort (Dhaka)/0cf09530-999a-466f-8459-5878817cfa78.jpg
# Removing corrupted image: dataset_places/Lalbagh Fort (Dhaka)/2299b9b7-be57-4435-9a2b-ad6b163acf6d.jpg
# Removing corrupted image: dataset_places/Lalbagh Fort (Dhaka)/_urls_attempt2.txt
# Removing corrupted image: dataset_places/Lalbagh Fort (Dhaka)/54c1e653-b0a2-4fbd-8be4-3327dc732199.jpg
# Removing corrupted image: dataset_places/Lalbagh Fort (Dhaka)/b7091734-2eb5-4599-9c78-250546e3b8fa.jpg
# Removing corrupted image: dataset_places/Lalbagh Fort (Dhaka)/_urls_attempt3.txt
# Removing corrupted image: dataset_places/Lalbagh Fort (Dhaka)/d175fbb3-f65c-408e-98ea-c0a209b3f74e.jpg
# Removing corrupted image: dataset_places/Lalbagh Fort (Dhaka)/0b18df82-c732-4e2b-ba01-a13f8a0bc346.jpg
# Removing corrupted image: dataset_places/Lalbagh Fort (Dhaka)/_urls_attempt4.txt
# Removing corrupted image: dataset_places/Lalbagh Fort (Dhaka)/2243580c-729a-404c-846a-28e233902f78.jpg
# Removing corrupted image: dataset_places/Lalbagh Fort (Dhaka)/f450cde2-a625-479e-b34a-945bdbd07c37.jpg
# Removing corrupted image: dataset_places/Lalbagh Fort (Dhaka)/_urls_attempt5.txt
# Removing corrupted image: dataset_places/Lalbagh Fort (Dhaka)/f86ba874-4131-48ad-932e-4d33b86b70df.jpg
# Removing corrupted image: dataset_places/Lalbagh Fort (Dhaka)/2cf385c2-06a8-431e-8d6b-f8dcc74582da.jpg
# Removing corrupted image: dataset_places/Lalbagh Fort (Dhaka)/_urls_attempt6.txt
# Removing corrupted image: dataset_places/Lalbagh Fort (Dhaka)/b29adac8-37b6-46b1-b486-23623edbca28.jpg
# Removing corrupted image: dataset_places/Lalbagh Fort (Dhaka)/bc8c9f74-a125-4bf5-a129-c3ca34985ef0.jpg
# Removing corrupted image: dataset_places/Dhaka Shaheed Minar (Bangladesh)/_urls_attempt1.txt
# Removing corrupted image: dataset_places/Dhaka Shaheed Minar (Bangladesh)/_urls_attempt2.txt
# Removing corrupted image: dataset_places/Dhaka Shaheed Minar (Bangladesh)/_urls_attempt3.txt
# Removing corrupted image: dataset_places/Dhaka Shaheed Minar (Bangladesh)/_urls_attempt4.txt
# Removing corrupted image: dataset_places/Dhaka Shaheed Minar (Bangladesh)/_urls_attempt5.txt
# Removing corrupted image: dataset_places/Dhaka Shaheed Minar (Bangladesh)/_urls_attempt6.txt
# Removing corrupted image: dataset_places/Sixty Dome Mosque (Bagerhat)/_urls_attempt1.txt
# Removing corrupted image: dataset_places/Sixty Dome Mosque (Bagerhat)/_urls_attempt2.txt
# Removing corrupted image: dataset_places/Sixty Dome Mosque (Bagerhat)/_urls_attempt3.txt
# Removing corrupted image: dataset_places/Sixty Dome Mosque (Bagerhat)/_urls_attempt4.txt
# Removing corrupted image: dataset_places/Sixty Dome Mosque (Bagerhat)/_urls_attempt5.txt
# Removing corrupted image: dataset_places/Sixty Dome Mosque (Bagerhat)/_urls_attempt6.txt
# Removing corrupted image: dataset_places/Somapura Mahavihara (Paharpur, Naogaon)/_urls_attempt1.txt
# Removing corrupted image: dataset_places/Somapura Mahavihara (Paharpur, Naogaon)/780c1f01-1c03-4815-861f-a6004cea3258.jpg
# Removing corrupted image: dataset_places/Somapura Mahavihara (Paharpur, Naogaon)/960d584b-5f16-4e46-b5fe-6985e2b5b3a4.jpg
# Removing corrupted image: dataset_places/Somapura Mahavihara (Paharpur, Naogaon)/_urls_attempt2.txt
# Removing corrupted image: dataset_places/Somapura Mahavihara (Paharpur, Naogaon)/0a6b0165-de8d-4482-b130-2254acfbbef9.jpg
# Removing corrupted image: dataset_places/Somapura Mahavihara (Paharpur, Naogaon)/_urls_attempt3.txt
# Removing corrupted image: dataset_places/Somapura Mahavihara (Paharpur, Naogaon)/a0a88a19-28da-486f-bd2c-14f5e33a4615.jpg
# Removing corrupted image: dataset_places/Somapura Mahavihara (Paharpur, Naogaon)/_urls_attempt4.txt
# Removing corrupted image: dataset_places/Somapura Mahavihara (Paharpur, Naogaon)/c0424775-e45b-4df5-a701-5242a3c6e4c9.jpg
# Removing corrupted image: dataset_places/Somapura Mahavihara (Paharpur, Naogaon)/_urls_attempt5.txt
# Removing corrupted image: dataset_places/Somapura Mahavihara (Paharpur, Naogaon)/2e65aa93-2b59-4712-9449-ac2005ea4f35.jpg
# Removing corrupted image: dataset_places/Somapura Mahavihara (Paharpur, Naogaon)/_urls_attempt6.txt
# Removing corrupted image: dataset_places/Somapura Mahavihara (Paharpur, Naogaon)/c4f85de6-342d-469a-ba20-af6c580833be.jpg
# Removing corrupted image: dataset_places/Kantajew Temple (Dinajpur)/_urls_attempt1.txt
# Removing corrupted image: dataset_places/Kantajew Temple (Dinajpur)/cf32192f-0e0c-48f8-b375-d84e01ab2167.jpg
# Removing corrupted image: dataset_places/Kantajew Temple (Dinajpur)/_urls_attempt2.txt
# Removing corrupted image: dataset_places/Kantajew Temple (Dinajpur)/_urls_attempt3.txt
# Removing corrupted image: dataset_places/Kantajew Temple (Dinajpur)/_urls_attempt4.txt
# Removing corrupted image: dataset_places/Kantajew Temple (Dinajpur)/12703779-b7dc-4346-8561-a161b28e702e.jpg
# Removing corrupted image: dataset_places/Kantajew Temple (Dinajpur)/_urls_attempt5.txt
# Removing corrupted image: dataset_places/Kantajew Temple (Dinajpur)/_urls_attempt6.txt
# Removing corrupted image: dataset_places/Kantajew Temple (Dinajpur)/_urls_attempt7.txt
# Removing corrupted image: dataset_places/Panam Nagar (Sonargaon, Narayanganj)/_urls_attempt1.txt
# Removing corrupted image: dataset_places/Panam Nagar (Sonargaon, Narayanganj)/_urls_attempt2.txt
# Removing corrupted image: dataset_places/Panam Nagar (Sonargaon, Narayanganj)/_urls_attempt3.txt
# Removing corrupted image: dataset_places/Panam Nagar (Sonargaon, Narayanganj)/_urls_attempt4.txt
# Removing corrupted image: dataset_places/Panam Nagar (Sonargaon, Narayanganj)/_urls_attempt5.txt
# Removing corrupted image: dataset_places/Panam Nagar (Sonargaon, Narayanganj)/_urls_attempt6.txt
# Removing corrupted image: dataset_places/Tajhat Palace (Rangpur)/_urls_attempt1.txt
# Removing corrupted image: dataset_places/Tajhat Palace (Rangpur)/b7f487bf-1ee7-4c6c-9ca4-248c87a0d566.jpg
# Removing corrupted image: dataset_places/Tajhat Palace (Rangpur)/e552b1df-9fa8-42db-ad60-7b11701b57ba.jpg
# Removing corrupted image: dataset_places/Tajhat Palace (Rangpur)/01844190-76d2-4cce-b199-2c0b335c551b.jpg
# Removing corrupted image: dataset_places/Tajhat Palace (Rangpur)/f5978682-511e-4747-b7e1-16e203b0ac4e.jpg
# Removing corrupted image: dataset_places/Tajhat Palace (Rangpur)/_urls_attempt2.txt
# Removing corrupted image: dataset_places/Tajhat Palace (Rangpur)/c0ceb880-7502-464f-8ecf-10818647823c.jpg
# Removing corrupted image: dataset_places/Tajhat Palace (Rangpur)/d7c3dfc7-c54b-49c2-8005-ffcb9d4c6525.jpg
# Removing corrupted image: dataset_places/Tajhat Palace (Rangpur)/b06e13e9-9168-4e4c-b7c2-444255d0df1f.jpg
# Removing corrupted image: dataset_places/Tajhat Palace (Rangpur)/_urls_attempt3.txt
# Removing corrupted image: dataset_places/Tajhat Palace (Rangpur)/092fca01-e3f3-4ce3-b971-16764731bc93.jpg
# Removing corrupted image: dataset_places/Tajhat Palace (Rangpur)/0ab14cd0-7723-4f0a-8067-249c7ba3198b.jpg
# Removing corrupted image: dataset_places/Tajhat Palace (Rangpur)/4ac4e117-0d42-461f-8bf1-e661a0835e63.jpg
# Removing corrupted image: dataset_places/Tajhat Palace (Rangpur)/_urls_attempt4.txt
# Removing corrupted image: dataset_places/Tajhat Palace (Rangpur)/e137a837-6cf8-4651-b4d2-1fe73829c483.jpg
# Removing corrupted image: dataset_places/Tajhat Palace (Rangpur)/19d186f1-a08e-4656-8e03-b0d3ffe5afda.jpg
# Removing corrupted image: dataset_places/Tajhat Palace (Rangpur)/5ab25c25-3acf-4575-bc37-b005dd40951c.jpg
# Removing corrupted image: dataset_places/Tajhat Palace (Rangpur)/_urls_attempt5.txt
# Removing corrupted image: dataset_places/Tajhat Palace (Rangpur)/63e9802d-8556-439f-be22-e5140943eb79.jpg
# Removing corrupted image: dataset_places/Tajhat Palace (Rangpur)/f4a621d8-d23a-4880-a43a-5c4dafceebce.jpg
# Removing corrupted image: dataset_places/Tajhat Palace (Rangpur)/_urls_attempt6.txt
# Removing corrupted image: dataset_places/Tajhat Palace (Rangpur)/d9aa8aaa-a98d-49aa-8a4d-19850045e279.jpg
# Removing corrupted image: dataset_places/Tajhat Palace (Rangpur)/95259240-76fb-42b8-bfc8-ee7634593f81.jpg
# Removing corrupted image: dataset_places/Tajhat Palace (Rangpur)/965171c6-8cdc-49e1-bff7-beb9390c5fef.jpg
# Removing corrupted image: dataset_places/Tajhat Palace (Rangpur)/_urls_attempt7.txt
# Removing corrupted image: dataset_places/Coxs Bazar Sea Beach (Coxs Bazar)/_urls_attempt1.txt
# Removing corrupted image: dataset_places/Coxs Bazar Sea Beach (Coxs Bazar)/9bc4141c-31d5-4cc2-ab6b-0b8891d3f3c3.jpg
# Removing corrupted image: dataset_places/Coxs Bazar Sea Beach (Coxs Bazar)/_urls_attempt2.txt
# Removing corrupted image: dataset_places/Coxs Bazar Sea Beach (Coxs Bazar)/20a34f7a-8bb1-4417-88a0-43333a77a6cc.jpg
# Removing corrupted image: dataset_places/Coxs Bazar Sea Beach (Coxs Bazar)/_urls_attempt3.txt
# Removing corrupted image: dataset_places/Coxs Bazar Sea Beach (Coxs Bazar)/c63541f2-299e-4401-93a1-c1ecc8e3b643.jpg
# Removing corrupted image: dataset_places/Coxs Bazar Sea Beach (Coxs Bazar)/_urls_attempt4.txt
# Removing corrupted image: dataset_places/Coxs Bazar Sea Beach (Coxs Bazar)/224c14c3-3bbd-4379-a6f9-4071d4b7794b.jpg
# Removing corrupted image: dataset_places/Coxs Bazar Sea Beach (Coxs Bazar)/_urls_attempt5.txt
# Removing corrupted image: dataset_places/Coxs Bazar Sea Beach (Coxs Bazar)/942a8dc2-6bd3-4eef-960c-9e10b49f12c2.jpg
# Removing corrupted image: dataset_places/Coxs Bazar Sea Beach (Coxs Bazar)/_urls_attempt6.txt
# Removing corrupted image: dataset_places/St. Martin's Island (Teknaf, Chhera Dwip)/_urls_attempt1.txt
# Removing corrupted image: dataset_places/St. Martin's Island (Teknaf, Chhera Dwip)/088e65f9-eeb0-4ec7-a096-39d7ee3a902b.jpg
# Removing corrupted image: dataset_places/St. Martin's Island (Teknaf, Chhera Dwip)/_urls_attempt2.txt
# Removing corrupted image: dataset_places/St. Martin's Island (Teknaf, Chhera Dwip)/01b2fef7-d595-48c3-800d-fe52f15eb9c5.jpg
# Removing corrupted image: dataset_places/St. Martin's Island (Teknaf, Chhera Dwip)/3c09f76c-3687-4221-b80f-f3b12f9042a0.jpg
# Removing corrupted image: dataset_places/St. Martin's Island (Teknaf, Chhera Dwip)/_urls_attempt3.txt
# Removing corrupted image: dataset_places/St. Martin's Island (Teknaf, Chhera Dwip)/b0673b17-60d4-4f7f-8b21-7cc1cddda78d.jpg
# Removing corrupted image: dataset_places/St. Martin's Island (Teknaf, Chhera Dwip)/_urls_attempt4.txt
# Removing corrupted image: dataset_places/St. Martin's Island (Teknaf, Chhera Dwip)/2bab571f-3ba0-40a9-ba86-ffa83b9dc5e9.jpg
# Removing corrupted image: dataset_places/St. Martin's Island (Teknaf, Chhera Dwip)/_urls_attempt5.txt
# Removing corrupted image: dataset_places/St. Martin's Island (Teknaf, Chhera Dwip)/2ee519d9-69d9-4764-9f28-f99874070b18.jpg
# Removing corrupted image: dataset_places/St. Martin's Island (Teknaf, Chhera Dwip)/_urls_attempt6.txt
# Removing corrupted image: dataset_places/St. Martin's Island (Teknaf, Chhera Dwip)/11e112e4-692d-4ebd-bf2a-bcf3bf4c7a7e.jpg
# Removing corrupted image: dataset_places/Sundarbans Mangrove Forest (Khulna)e/_urls_attempt1.txt
# Removing corrupted image: dataset_places/Sundarbans Mangrove Forest (Khulna)e/6c00cc00-9c5b-4d34-8f97-bd20b2837e85.webp
# Removing corrupted image: dataset_places/Sundarbans Mangrove Forest (Khulna)e/_urls_attempt2.txt
# Removing corrupted image: dataset_places/Sundarbans Mangrove Forest (Khulna)e/440fefed-fc2d-4ca5-8cb2-1cbdfb846282.webp
# Removing corrupted image: dataset_places/Sundarbans Mangrove Forest (Khulna)e/_urls_attempt3.txt
# Removing corrupted image: dataset_places/Sundarbans Mangrove Forest (Khulna)e/09b67ac4-b6b4-448b-b1b5-3cb805995466.webp
# Removing corrupted image: dataset_places/Sundarbans Mangrove Forest (Khulna)e/_urls_attempt4.txt
# Removing corrupted image: dataset_places/Sundarbans Mangrove Forest (Khulna)e/0dba1d4d-3d3e-4c06-8911-b8745cc85b06.webp
# Removing corrupted image: dataset_places/Sundarbans Mangrove Forest (Khulna)e/_urls_attempt5.txt
# Removing corrupted image: dataset_places/Sundarbans Mangrove Forest (Khulna)e/_urls_attempt6.txt
# Removing corrupted image: dataset_places/Sundarbans Mangrove Forest (Khulna)e/ea676efb-7888-4e45-9a9c-650f77967046.webp
# Removing corrupted image: dataset_places/Jaflong (Sylhet)/_urls_attempt1.txt
# Removing corrupted image: dataset_places/Jaflong (Sylhet)/_urls_attempt2.txt
# Removing corrupted image: dataset_places/Jaflong (Sylhet)/_urls_attempt3.txt
# Removing corrupted image: dataset_places/Jaflong (Sylhet)/_urls_attempt4.txt
# Removing corrupted image: dataset_places/Jaflong (Sylhet)/_urls_attempt5.txt
# Removing corrupted image: dataset_places/Jaflong (Sylhet)/_urls_attempt6.txt
# Removing corrupted image: dataset_places/Ratargul Swamp Forest (Sylhet)/_urls_attempt1.txt
# Removing corrupted image: dataset_places/Ratargul Swamp Forest (Sylhet)/_urls_attempt2.txt
# Removing corrupted image: dataset_places/Ratargul Swamp Forest (Sylhet)/_urls_attempt3.txt
# Removing corrupted image: dataset_places/Ratargul Swamp Forest (Sylhet)/_urls_attempt4.txt
# Removing corrupted image: dataset_places/Ratargul Swamp Forest (Sylhet)/_urls_attempt5.txt
# Removing corrupted image: dataset_places/Ratargul Swamp Forest (Sylhet)/_urls_attempt6.txt
# Removing corrupted image: dataset_places/Sajek Valley (Rangamati)/_urls_attempt1.txt
# Removing corrupted image: dataset_places/Sajek Valley (Rangamati)/_urls_attempt2.txt
# Removing corrupted image: dataset_places/Sajek Valley (Rangamati)/_urls_attempt3.txt
# Removing corrupted image: dataset_places/Sajek Valley (Rangamati)/_urls_attempt4.txt
# Removing corrupted image: dataset_places/Sajek Valley (Rangamati)/_urls_attempt5.txt
# Removing corrupted image: dataset_places/Sajek Valley (Rangamati)/_urls_attempt6.txt
# Removing corrupted image: dataset_places/Nafakhum Waterfall (Bandarban)/_urls_attempt1.txt
# Removing corrupted image: dataset_places/Nafakhum Waterfall (Bandarban)/25c33e8e-f325-4dd3-87e5-ae932d126a79.jpg
# Removing corrupted image: dataset_places/Nafakhum Waterfall (Bandarban)/_urls_attempt2.txt
# Removing corrupted image: dataset_places/Nafakhum Waterfall (Bandarban)/459c5cd0-b18e-479d-adbb-5992890d898c.jpg
# Removing corrupted image: dataset_places/Nafakhum Waterfall (Bandarban)/_urls_attempt3.txt
# Removing corrupted image: dataset_places/Nafakhum Waterfall (Bandarban)/1658d262-8926-4a13-8f8a-b4209ab7a85c.jpg
# Removing corrupted image: dataset_places/Nafakhum Waterfall (Bandarban)/_urls_attempt4.txt
# Removing corrupted image: dataset_places/Nafakhum Waterfall (Bandarban)/032a2e1b-2793-4545-90f6-3619230df8aa.jpg
# Removing corrupted image: dataset_places/Nafakhum Waterfall (Bandarban)/_urls_attempt5.txt
# Removing corrupted image: dataset_places/Nafakhum Waterfall (Bandarban)/3949fdb9-2dc6-408a-9ebb-f0d29ca14d6b.jpg
# Removing corrupted image: dataset_places/Nafakhum Waterfall (Bandarban)/_urls_attempt6.txt
