# %%
# !pip install ddgs fastai tqdm --quiet

# %%
import os
from pathlib import Path
from ddgs import DDGS
from tqdm.notebook import tqdm
from fastai.vision.utils import download_images, verify_images

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/MasterCourse/Bangladeshi_Landmarks
# Out:
# /content/drive/MyDrive/MasterCourse/Bangladeshi_Landmarks

# %%
DEST_ROOT = Path("dataset_places1")
DEST_ROOT.mkdir(parents=True, exist_ok=True)

TARGET_PER_CLASS = 1050
OVERFETCH_FACTOR = 2
MAX_RETRIES =15

ARCH_HINT = (
    "exterior architecture building monument facade heritage "
    "-interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding"
)
NATURE_HINT = (
    "landscape scenery nature hills forest river mountain valley beach waterfall "
    "-selfie -people -tourist -crowd -group -human -face -portrait"
)

places = [
    "Jatiya Sangsad Bhaban (Dhaka) Architecture only",
    "Ahsan Manzil (Dhaka) Architecture only",
    "Lalbagh Fort (Dhaka) Architecture only",
    "Dhaka Shaheed Minar (Bangladesh) Architecture only",
    "Sixty Dome Mosque (Bagerhat) Architecture only",
    "Somapura Mahavihara (Paharpur, Naogaon) Architecture only",
    "Kantajew Temple (Dinajpur) Architecture only",
    "Panam Nagar (Sonargaon, Narayanganj) Architecture only",
    "Tajhat Palace (Rangpur) Architecture only",
    "Cox’s Bazar Sea Beach (Cox’s Bazar) Nature only",
    "St. Martin's Island (Teknaf, Chhera Dwip) Nature only",
    "Sundarbans Mangrove Forest (Khulna) Nature only",
    "Jaflong (Sylhet) Nature only",
    "Ratargul Swamp Forest (Sylhet) Nature only",
    "Sajek Valley (Rangamati) Nature only",
    "Nafakhum Waterfall (Bandarban) Nature only"
]

# %%
def split_name_and_type(item: str):
    if "Architecture" in item:
        return item.replace(" Architecture only", "").strip(), "Architecture"
    elif "Nature" in item:
        return item.replace(" Nature only", "").strip(), "Nature"
    return item, "Unknown"

def build_query(place_name: str, kind: str, attempt: int) -> str:
    if kind == "Architecture":
        base = f"{place_name} {ARCH_HINT}"
    elif kind == "Nature":
        base = f"{place_name} {NATURE_HINT}"
    else:
        base = place_name
    if attempt > 0:
        base += f" photo view picture {attempt}"
    return base

def duckduckgo_search(query: str, needed: int):
    urls, seen = [], set()
    try:
        with DDGS() as ddgs:
            for r in ddgs.images(query, safesearch="on", type_image="photo", max_results=needed*2):
                url = r.get("image")
                if not url or url in seen:
                    continue
                if any(bad in url.lower() for bad in ["svg", "base64,", "data:image"]):
                    continue
                seen.add(url)
                urls.append(url)
                if len(urls) >= needed:
                    break
    except Exception as e:
        print(f"[!] DuckDuckGo search failed: {e}")
    return urls

def sanitize_dirname(name: str) -> str:
    return "".join(c for c in name if c.isalnum() or c in " -_()&',.").strip()

def ensure_target_count(folder: Path) -> int:
    exts = {".jpg", ".jpeg", ".png", ".bmp", ".gif", ".webp"}
    return sum(1 for p in folder.glob("*") if p.suffix.lower() in exts)

# %%
summary = []

for item in places:
    place_name, kind = split_name_and_type(item)
    class_dir = DEST_ROOT / sanitize_dirname(place_name)
    class_dir.mkdir(parents=True, exist_ok=True)

    for attempt in range(MAX_RETRIES):
        have = ensure_target_count(class_dir)
        if have >= TARGET_PER_CLASS:
            print(f"[✓] {place_name}: reached {have}/{TARGET_PER_CLASS} images.")
            break

        need = TARGET_PER_CLASS - have
        urls_needed = int(need * OVERFETCH_FACTOR)
        query = build_query(place_name, kind, attempt)

        print(f"\n=== {place_name} ({kind}) | Attempt {attempt+1} ===")
        print(f"Query: {query}")
        print(f"Need {need} more images (fetching {urls_needed} URLs).")

        urls = duckduckgo_search(query, urls_needed)
        if not urls:
            print(f"[!] No URLs found this attempt.")
            continue

        urls_file = class_dir / f"_urls_attempt{attempt+1}.txt"
        urls_file.write_text("\n".join(urls), encoding="utf-8")
        urls_list = urls_file.read_text().splitlines()
        download_images(str(class_dir), urls=urls_list, preserve_filename=False, timeout=30, n_workers=8)
        failed = verify_images(str(class_dir))
        if failed:
            print(f"Removed {len(failed)} corrupt images.")

        final_count = ensure_target_count(class_dir)
        print(f"[i] {place_name}: now {final_count}/{TARGET_PER_CLASS} images.")

    final_count = ensure_target_count(class_dir)
    status = "OK" if final_count >= TARGET_PER_CLASS else "SHORT"
    summary.append((place_name, kind, final_count, status))
# Out:
# === Jatiya Sangsad Bhaban (Dhaka) (Architecture) | Attempt 1 ===
# Query: Jatiya Sangsad Bhaban (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding
# Need 1050 more images (fetching 2100 URLs).
# Removed 45 corrupt images.
# [i] Jatiya Sangsad Bhaban (Dhaka): now 81/1050 images.
#
# === Jatiya Sangsad Bhaban (Dhaka) (Architecture) | Attempt 2 ===
# Query: Jatiya Sangsad Bhaban (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 1
# Need 969 more images (fetching 1938 URLs).
# Removed 45 corrupt images.
# [i] Jatiya Sangsad Bhaban (Dhaka): now 165/1050 images.
#
# === Jatiya Sangsad Bhaban (Dhaka) (Architecture) | Attempt 3 ===
# Query: Jatiya Sangsad Bhaban (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 2
# Need 885 more images (fetching 1770 URLs).
# Removed 45 corrupt images.
# [i] Jatiya Sangsad Bhaban (Dhaka): now 250/1050 images.
#
# === Jatiya Sangsad Bhaban (Dhaka) (Architecture) | Attempt 4 ===
# Query: Jatiya Sangsad Bhaban (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 3
# Need 800 more images (fetching 1600 URLs).
# Removed 45 corrupt images.
# [i] Jatiya Sangsad Bhaban (Dhaka): now 332/1050 images.
#
# === Jatiya Sangsad Bhaban (Dhaka) (Architecture) | Attempt 5 ===
# Query: Jatiya Sangsad Bhaban (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 4
# Need 718 more images (fetching 1436 URLs).
# Removed 45 corrupt images.
# [i] Jatiya Sangsad Bhaban (Dhaka): now 415/1050 images.
#
# === Jatiya Sangsad Bhaban (Dhaka) (Architecture) | Attempt 6 ===
# Query: Jatiya Sangsad Bhaban (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 5
# Need 635 more images (fetching 1270 URLs).
# Removed 45 corrupt images.
# [i] Jatiya Sangsad Bhaban (Dhaka): now 500/1050 images.
#
# === Jatiya Sangsad Bhaban (Dhaka) (Architecture) | Attempt 7 ===
# Query: Jatiya Sangsad Bhaban (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 6
# Need 550 more images (fetching 1100 URLs).
# Removed 45 corrupt images.
# [i] Jatiya Sangsad Bhaban (Dhaka): now 582/1050 images.
#
# === Jatiya Sangsad Bhaban (Dhaka) (Architecture) | Attempt 8 ===
# Query: Jatiya Sangsad Bhaban (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 7
# Need 468 more images (fetching 936 URLs).
# Removed 45 corrupt images.
# [i] Jatiya Sangsad Bhaban (Dhaka): now 665/1050 images.
#
# === Jatiya Sangsad Bhaban (Dhaka) (Architecture) | Attempt 9 ===
# Query: Jatiya Sangsad Bhaban (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 8
# Need 385 more images (fetching 770 URLs).
# Removed 45 corrupt images.
# [i] Jatiya Sangsad Bhaban (Dhaka): now 747/1050 images.
#
# === Jatiya Sangsad Bhaban (Dhaka) (Architecture) | Attempt 10 ===
# Query: Jatiya Sangsad Bhaban (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 9
# Need 303 more images (fetching 606 URLs).
# Removed 45 corrupt images.
# [i] Jatiya Sangsad Bhaban (Dhaka): now 828/1050 images.
#
# === Jatiya Sangsad Bhaban (Dhaka) (Architecture) | Attempt 11 ===
# Query: Jatiya Sangsad Bhaban (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 10
# Need 222 more images (fetching 444 URLs).
# Removed 45 corrupt images.
# [i] Jatiya Sangsad Bhaban (Dhaka): now 912/1050 images.
#
# === Jatiya Sangsad Bhaban (Dhaka) (Architecture) | Attempt 12 ===
# Query: Jatiya Sangsad Bhaban (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 11
# Need 138 more images (fetching 276 URLs).
# Removed 45 corrupt images.
# [i] Jatiya Sangsad Bhaban (Dhaka): now 996/1050 images.
#
# === Jatiya Sangsad Bhaban (Dhaka) (Architecture) | Attempt 13 ===
# Query: Jatiya Sangsad Bhaban (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 12
# Need 54 more images (fetching 108 URLs).
# Removed 45 corrupt images.
# [i] Jatiya Sangsad Bhaban (Dhaka): now 1079/1050 images.
# [✓] Jatiya Sangsad Bhaban (Dhaka): reached 1079/1050 images.
#
# === Ahsan Manzil (Dhaka) (Architecture) | Attempt 1 ===
# Query: Ahsan Manzil (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding
# Need 1050 more images (fetching 2100 URLs).
# Removed 36 corrupt images.
# [i] Ahsan Manzil (Dhaka): now 91/1050 images.
#
# === Ahsan Manzil (Dhaka) (Architecture) | Attempt 2 ===
# Query: Ahsan Manzil (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 1
# Need 959 more images (fetching 1918 URLs).
# Removed 36 corrupt images.
# [i] Ahsan Manzil (Dhaka): now 184/1050 images.
#
# === Ahsan Manzil (Dhaka) (Architecture) | Attempt 3 ===
# Query: Ahsan Manzil (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 2
# Need 866 more images (fetching 1732 URLs).
# Removed 36 corrupt images.
# [i] Ahsan Manzil (Dhaka): now 274/1050 images.
#
# === Ahsan Manzil (Dhaka) (Architecture) | Attempt 4 ===
# Query: Ahsan Manzil (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 3
# Need 776 more images (fetching 1552 URLs).
# Removed 36 corrupt images.
# [i] Ahsan Manzil (Dhaka): now 367/1050 images.
#
# === Ahsan Manzil (Dhaka) (Architecture) | Attempt 5 ===
# Query: Ahsan Manzil (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 4
# Need 683 more images (fetching 1366 URLs).
# Removed 36 corrupt images.
# [i] Ahsan Manzil (Dhaka): now 459/1050 images.
#
# === Ahsan Manzil (Dhaka) (Architecture) | Attempt 6 ===
# Query: Ahsan Manzil (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 5
# Need 591 more images (fetching 1182 URLs).
# Removed 36 corrupt images.
# [i] Ahsan Manzil (Dhaka): now 551/1050 images.
#
# === Ahsan Manzil (Dhaka) (Architecture) | Attempt 7 ===
# Query: Ahsan Manzil (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 6
# Need 499 more images (fetching 998 URLs).
# Removed 36 corrupt images.
# [i] Ahsan Manzil (Dhaka): now 645/1050 images.
#
# === Ahsan Manzil (Dhaka) (Architecture) | Attempt 8 ===
# Query: Ahsan Manzil (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 7
# Need 405 more images (fetching 810 URLs).
# Removed 36 corrupt images.
# [i] Ahsan Manzil (Dhaka): now 737/1050 images.
#
# === Ahsan Manzil (Dhaka) (Architecture) | Attempt 9 ===
# Query: Ahsan Manzil (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 8
# Need 313 more images (fetching 626 URLs).
# Removed 36 corrupt images.
# [i] Ahsan Manzil (Dhaka): now 828/1050 images.
#
# === Ahsan Manzil (Dhaka) (Architecture) | Attempt 10 ===
# Query: Ahsan Manzil (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 9
# Need 222 more images (fetching 444 URLs).
# Removed 36 corrupt images.
# [i] Ahsan Manzil (Dhaka): now 921/1050 images.
#
# === Ahsan Manzil (Dhaka) (Architecture) | Attempt 11 ===
# Query: Ahsan Manzil (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 10
# Need 129 more images (fetching 258 URLs).
# Removed 36 corrupt images.
# [i] Ahsan Manzil (Dhaka): now 1014/1050 images.
#
# === Ahsan Manzil (Dhaka) (Architecture) | Attempt 12 ===
# Query: Ahsan Manzil (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 11
# Need 36 more images (fetching 72 URLs).
# Removed 36 corrupt images.
# [i] Ahsan Manzil (Dhaka): now 1082/1050 images.
# [✓] Ahsan Manzil (Dhaka): reached 1082/1050 images.
#
# === Lalbagh Fort (Dhaka) (Architecture) | Attempt 1 ===
# Query: Lalbagh Fort (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding
# Need 1050 more images (fetching 2100 URLs).
# Removed 36 corrupt images.
# [i] Lalbagh Fort (Dhaka): now 85/1050 images.
#
# === Lalbagh Fort (Dhaka) (Architecture) | Attempt 2 ===
# Query: Lalbagh Fort (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 1
# Need 965 more images (fetching 1930 URLs).
# Removed 36 corrupt images.
# [i] Lalbagh Fort (Dhaka): now 169/1050 images.
#
# === Lalbagh Fort (Dhaka) (Architecture) | Attempt 3 ===
# Query: Lalbagh Fort (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 2
# Need 881 more images (fetching 1762 URLs).
# Removed 36 corrupt images.
# [i] Lalbagh Fort (Dhaka): now 255/1050 images.
#
# === Lalbagh Fort (Dhaka) (Architecture) | Attempt 4 ===
# Query: Lalbagh Fort (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 3
# Need 795 more images (fetching 1590 URLs).
# Removed 36 corrupt images.
# [i] Lalbagh Fort (Dhaka): now 341/1050 images.
#
# === Lalbagh Fort (Dhaka) (Architecture) | Attempt 5 ===
# Query: Lalbagh Fort (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 4
# Need 709 more images (fetching 1418 URLs).
# Removed 36 corrupt images.
# [i] Lalbagh Fort (Dhaka): now 424/1050 images.
#
# === Lalbagh Fort (Dhaka) (Architecture) | Attempt 6 ===
# Query: Lalbagh Fort (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 5
# Need 626 more images (fetching 1252 URLs).
# Removed 36 corrupt images.
# [i] Lalbagh Fort (Dhaka): now 507/1050 images.
#
# === Lalbagh Fort (Dhaka) (Architecture) | Attempt 7 ===
# Query: Lalbagh Fort (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 6
# Need 543 more images (fetching 1086 URLs).
# Removed 36 corrupt images.
# [i] Lalbagh Fort (Dhaka): now 591/1050 images.
#
# === Lalbagh Fort (Dhaka) (Architecture) | Attempt 8 ===
# Query: Lalbagh Fort (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 7
# Need 459 more images (fetching 918 URLs).
# Removed 36 corrupt images.
# [i] Lalbagh Fort (Dhaka): now 677/1050 images.
#
# === Lalbagh Fort (Dhaka) (Architecture) | Attempt 9 ===
# Query: Lalbagh Fort (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 8
# Need 373 more images (fetching 746 URLs).
# Removed 36 corrupt images.
# [i] Lalbagh Fort (Dhaka): now 759/1050 images.
#
# === Lalbagh Fort (Dhaka) (Architecture) | Attempt 10 ===
# Query: Lalbagh Fort (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 9
# Need 291 more images (fetching 582 URLs).
# Removed 36 corrupt images.
# [i] Lalbagh Fort (Dhaka): now 843/1050 images.
#
# === Lalbagh Fort (Dhaka) (Architecture) | Attempt 11 ===
# Query: Lalbagh Fort (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 10
# Need 207 more images (fetching 414 URLs).
# Removed 36 corrupt images.
# [i] Lalbagh Fort (Dhaka): now 928/1050 images.
#
# === Lalbagh Fort (Dhaka) (Architecture) | Attempt 12 ===
# Query: Lalbagh Fort (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 11
# Need 122 more images (fetching 244 URLs).
# Removed 36 corrupt images.
# [i] Lalbagh Fort (Dhaka): now 1013/1050 images.
#
# === Lalbagh Fort (Dhaka) (Architecture) | Attempt 13 ===
# Query: Lalbagh Fort (Dhaka) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 12
# Need 37 more images (fetching 74 URLs).
# Removed 36 corrupt images.
# [i] Lalbagh Fort (Dhaka): now 1077/1050 images.
# [✓] Lalbagh Fort (Dhaka): reached 1077/1050 images.
#
# === Dhaka Shaheed Minar (Bangladesh) (Architecture) | Attempt 1 ===
# Query: Dhaka Shaheed Minar (Bangladesh) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding
# Need 1050 more images (fetching 2100 URLs).
# Removed 48 corrupt images.
# [i] Dhaka Shaheed Minar (Bangladesh): now 88/1050 images.
#
# === Dhaka Shaheed Minar (Bangladesh) (Architecture) | Attempt 2 ===
# Query: Dhaka Shaheed Minar (Bangladesh) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 1
# Need 962 more images (fetching 1924 URLs).
# Removed 48 corrupt images.
# [i] Dhaka Shaheed Minar (Bangladesh): now 178/1050 images.
#
# === Dhaka Shaheed Minar (Bangladesh) (Architecture) | Attempt 3 ===
# Query: Dhaka Shaheed Minar (Bangladesh) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 2
# Need 872 more images (fetching 1744 URLs).
# Removed 48 corrupt images.
# [i] Dhaka Shaheed Minar (Bangladesh): now 268/1050 images.
#
# === Dhaka Shaheed Minar (Bangladesh) (Architecture) | Attempt 4 ===
# Query: Dhaka Shaheed Minar (Bangladesh) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 3
# Need 782 more images (fetching 1564 URLs).
# Removed 48 corrupt images.
# [i] Dhaka Shaheed Minar (Bangladesh): now 358/1050 images.
#
# === Dhaka Shaheed Minar (Bangladesh) (Architecture) | Attempt 5 ===
# Query: Dhaka Shaheed Minar (Bangladesh) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 4
# Need 692 more images (fetching 1384 URLs).
# Removed 48 corrupt images.
# [i] Dhaka Shaheed Minar (Bangladesh): now 447/1050 images.
#
# === Dhaka Shaheed Minar (Bangladesh) (Architecture) | Attempt 6 ===
# Query: Dhaka Shaheed Minar (Bangladesh) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 5
# Need 603 more images (fetching 1206 URLs).
# Removed 48 corrupt images.
# [i] Dhaka Shaheed Minar (Bangladesh): now 536/1050 images.
#
# === Dhaka Shaheed Minar (Bangladesh) (Architecture) | Attempt 7 ===
# Query: Dhaka Shaheed Minar (Bangladesh) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 6
# Need 514 more images (fetching 1028 URLs).
# Removed 48 corrupt images.
# [i] Dhaka Shaheed Minar (Bangladesh): now 624/1050 images.
#
# === Dhaka Shaheed Minar (Bangladesh) (Architecture) | Attempt 8 ===
# Query: Dhaka Shaheed Minar (Bangladesh) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 7
# Need 426 more images (fetching 852 URLs).
# Removed 48 corrupt images.
# [i] Dhaka Shaheed Minar (Bangladesh): now 713/1050 images.
#
# === Dhaka Shaheed Minar (Bangladesh) (Architecture) | Attempt 9 ===
# Query: Dhaka Shaheed Minar (Bangladesh) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 8
# Need 337 more images (fetching 674 URLs).
# Removed 48 corrupt images.
# [i] Dhaka Shaheed Minar (Bangladesh): now 802/1050 images.
#
# === Dhaka Shaheed Minar (Bangladesh) (Architecture) | Attempt 10 ===
# Query: Dhaka Shaheed Minar (Bangladesh) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 9
# Need 248 more images (fetching 496 URLs).
# Removed 48 corrupt images.
# [i] Dhaka Shaheed Minar (Bangladesh): now 889/1050 images.
#
# === Dhaka Shaheed Minar (Bangladesh) (Architecture) | Attempt 11 ===
# Query: Dhaka Shaheed Minar (Bangladesh) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 10
# Need 161 more images (fetching 322 URLs).
# Removed 48 corrupt images.
# [i] Dhaka Shaheed Minar (Bangladesh): now 980/1050 images.
#
# === Dhaka Shaheed Minar (Bangladesh) (Architecture) | Attempt 12 ===
# Query: Dhaka Shaheed Minar (Bangladesh) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 11
# Need 70 more images (fetching 140 URLs).
# Removed 48 corrupt images.
# [i] Dhaka Shaheed Minar (Bangladesh): now 1069/1050 images.
# [✓] Dhaka Shaheed Minar (Bangladesh): reached 1069/1050 images.
#
# === Sixty Dome Mosque (Bagerhat) (Architecture) | Attempt 1 ===
# Query: Sixty Dome Mosque (Bagerhat) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding
# Need 1050 more images (fetching 2100 URLs).
# Removed 44 corrupt images.
# [i] Sixty Dome Mosque (Bagerhat): now 92/1050 images.
#
# === Sixty Dome Mosque (Bagerhat) (Architecture) | Attempt 2 ===
# Query: Sixty Dome Mosque (Bagerhat) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 1
# Need 958 more images (fetching 1916 URLs).
# Removed 44 corrupt images.
# [i] Sixty Dome Mosque (Bagerhat): now 185/1050 images.
#
# === Sixty Dome Mosque (Bagerhat) (Architecture) | Attempt 3 ===
# Query: Sixty Dome Mosque (Bagerhat) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 2
# Need 865 more images (fetching 1730 URLs).
# Removed 44 corrupt images.
# [i] Sixty Dome Mosque (Bagerhat): now 277/1050 images.
#
# === Sixty Dome Mosque (Bagerhat) (Architecture) | Attempt 4 ===
# Query: Sixty Dome Mosque (Bagerhat) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 3
# Need 773 more images (fetching 1546 URLs).
# Removed 44 corrupt images.
# [i] Sixty Dome Mosque (Bagerhat): now 368/1050 images.
#
# === Sixty Dome Mosque (Bagerhat) (Architecture) | Attempt 5 ===
# Query: Sixty Dome Mosque (Bagerhat) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 4
# Need 682 more images (fetching 1364 URLs).
# Removed 44 corrupt images.
# [i] Sixty Dome Mosque (Bagerhat): now 461/1050 images.
#
# === Sixty Dome Mosque (Bagerhat) (Architecture) | Attempt 6 ===
# Query: Sixty Dome Mosque (Bagerhat) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 5
# Need 589 more images (fetching 1178 URLs).
# Removed 44 corrupt images.
# [i] Sixty Dome Mosque (Bagerhat): now 555/1050 images.
#
# === Sixty Dome Mosque (Bagerhat) (Architecture) | Attempt 7 ===
# Query: Sixty Dome Mosque (Bagerhat) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 6
# Need 495 more images (fetching 990 URLs).
# Removed 44 corrupt images.
# [i] Sixty Dome Mosque (Bagerhat): now 647/1050 images.
#
# === Sixty Dome Mosque (Bagerhat) (Architecture) | Attempt 8 ===
# Query: Sixty Dome Mosque (Bagerhat) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 7
# Need 403 more images (fetching 806 URLs).
# Removed 44 corrupt images.
# [i] Sixty Dome Mosque (Bagerhat): now 738/1050 images.
#
# === Sixty Dome Mosque (Bagerhat) (Architecture) | Attempt 9 ===
# Query: Sixty Dome Mosque (Bagerhat) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 8
# Need 312 more images (fetching 624 URLs).
# Removed 44 corrupt images.
# [i] Sixty Dome Mosque (Bagerhat): now 831/1050 images.
#
# === Sixty Dome Mosque (Bagerhat) (Architecture) | Attempt 10 ===
# Query: Sixty Dome Mosque (Bagerhat) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 9
# Need 219 more images (fetching 438 URLs).
# Removed 44 corrupt images.
# [i] Sixty Dome Mosque (Bagerhat): now 925/1050 images.
#
# === Sixty Dome Mosque (Bagerhat) (Architecture) | Attempt 11 ===
# Query: Sixty Dome Mosque (Bagerhat) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 10
# Need 125 more images (fetching 250 URLs).
# Removed 44 corrupt images.
# [i] Sixty Dome Mosque (Bagerhat): now 1017/1050 images.
#
# === Sixty Dome Mosque (Bagerhat) (Architecture) | Attempt 12 ===
# Query: Sixty Dome Mosque (Bagerhat) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 11
# Need 33 more images (fetching 66 URLs).
# Removed 44 corrupt images.
# [i] Sixty Dome Mosque (Bagerhat): now 1079/1050 images.
# [✓] Sixty Dome Mosque (Bagerhat): reached 1079/1050 images.
#
# === Somapura Mahavihara (Paharpur, Naogaon) (Architecture) | Attempt 1 ===
# Query: Somapura Mahavihara (Paharpur, Naogaon) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding
# Need 1050 more images (fetching 2100 URLs).
# Removed 55 corrupt images.
# [i] Somapura Mahavihara (Paharpur, Naogaon): now 98/1050 images.
#
# === Somapura Mahavihara (Paharpur, Naogaon) (Architecture) | Attempt 2 ===
# Query: Somapura Mahavihara (Paharpur, Naogaon) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 1
# Need 952 more images (fetching 1904 URLs).
# Removed 55 corrupt images.
# [i] Somapura Mahavihara (Paharpur, Naogaon): now 194/1050 images.
#
# === Somapura Mahavihara (Paharpur, Naogaon) (Architecture) | Attempt 3 ===
# Query: Somapura Mahavihara (Paharpur, Naogaon) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 2
# Need 856 more images (fetching 1712 URLs).
# Removed 55 corrupt images.
# [i] Somapura Mahavihara (Paharpur, Naogaon): now 288/1050 images.
#
# === Somapura Mahavihara (Paharpur, Naogaon) (Architecture) | Attempt 4 ===
# Query: Somapura Mahavihara (Paharpur, Naogaon) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 3
# Need 762 more images (fetching 1524 URLs).
# Removed 55 corrupt images.
# [i] Somapura Mahavihara (Paharpur, Naogaon): now 383/1050 images.
#
# === Somapura Mahavihara (Paharpur, Naogaon) (Architecture) | Attempt 5 ===
# Query: Somapura Mahavihara (Paharpur, Naogaon) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 4
# Need 667 more images (fetching 1334 URLs).
# Removed 55 corrupt images.
# [i] Somapura Mahavihara (Paharpur, Naogaon): now 478/1050 images.
#
# === Somapura Mahavihara (Paharpur, Naogaon) (Architecture) | Attempt 6 ===
# Query: Somapura Mahavihara (Paharpur, Naogaon) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 5
# Need 572 more images (fetching 1144 URLs).
# Removed 55 corrupt images.
# [i] Somapura Mahavihara (Paharpur, Naogaon): now 573/1050 images.
#
# === Somapura Mahavihara (Paharpur, Naogaon) (Architecture) | Attempt 7 ===
# Query: Somapura Mahavihara (Paharpur, Naogaon) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 6
# Need 477 more images (fetching 954 URLs).
# Removed 55 corrupt images.
# [i] Somapura Mahavihara (Paharpur, Naogaon): now 667/1050 images.
#
# === Somapura Mahavihara (Paharpur, Naogaon) (Architecture) | Attempt 8 ===
# Query: Somapura Mahavihara (Paharpur, Naogaon) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 7
# Need 383 more images (fetching 766 URLs).
# Removed 55 corrupt images.
# [i] Somapura Mahavihara (Paharpur, Naogaon): now 762/1050 images.
#
# === Somapura Mahavihara (Paharpur, Naogaon) (Architecture) | Attempt 9 ===
# Query: Somapura Mahavihara (Paharpur, Naogaon) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 8
# Need 288 more images (fetching 576 URLs).
# Removed 55 corrupt images.
# [i] Somapura Mahavihara (Paharpur, Naogaon): now 855/1050 images.
#
# === Somapura Mahavihara (Paharpur, Naogaon) (Architecture) | Attempt 10 ===
# Query: Somapura Mahavihara (Paharpur, Naogaon) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 9
# Need 195 more images (fetching 390 URLs).
# Removed 55 corrupt images.
# [i] Somapura Mahavihara (Paharpur, Naogaon): now 949/1050 images.
#
# === Somapura Mahavihara (Paharpur, Naogaon) (Architecture) | Attempt 11 ===
# Query: Somapura Mahavihara (Paharpur, Naogaon) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 10
# Need 101 more images (fetching 202 URLs).
# Removed 55 corrupt images.
# [i] Somapura Mahavihara (Paharpur, Naogaon): now 1044/1050 images.
#
# === Somapura Mahavihara (Paharpur, Naogaon) (Architecture) | Attempt 12 ===
# Query: Somapura Mahavihara (Paharpur, Naogaon) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 11
# Need 6 more images (fetching 12 URLs).
# Removed 55 corrupt images.
# [i] Somapura Mahavihara (Paharpur, Naogaon): now 1055/1050 images.
# [✓] Somapura Mahavihara (Paharpur, Naogaon): reached 1055/1050 images.
#
# === Kantajew Temple (Dinajpur) (Architecture) | Attempt 1 ===
# Query: Kantajew Temple (Dinajpur) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding
# Need 1050 more images (fetching 2100 URLs).
# Removed 42 corrupt images.
# [i] Kantajew Temple (Dinajpur): now 84/1050 images.
#
# === Kantajew Temple (Dinajpur) (Architecture) | Attempt 2 ===
# Query: Kantajew Temple (Dinajpur) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 1
# Need 966 more images (fetching 1932 URLs).
# Removed 42 corrupt images.
# [i] Kantajew Temple (Dinajpur): now 166/1050 images.
#
# === Kantajew Temple (Dinajpur) (Architecture) | Attempt 3 ===
# Query: Kantajew Temple (Dinajpur) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 2
# Need 884 more images (fetching 1768 URLs).
# Removed 42 corrupt images.
# [i] Kantajew Temple (Dinajpur): now 244/1050 images.
#
# === Kantajew Temple (Dinajpur) (Architecture) | Attempt 4 ===
# Query: Kantajew Temple (Dinajpur) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 3
# Need 806 more images (fetching 1612 URLs).
# Removed 42 corrupt images.
# [i] Kantajew Temple (Dinajpur): now 324/1050 images.
#
# === Kantajew Temple (Dinajpur) (Architecture) | Attempt 5 ===
# Query: Kantajew Temple (Dinajpur) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 4
# Need 726 more images (fetching 1452 URLs).
# Removed 42 corrupt images.
# [i] Kantajew Temple (Dinajpur): now 406/1050 images.
#
# === Kantajew Temple (Dinajpur) (Architecture) | Attempt 6 ===
# Query: Kantajew Temple (Dinajpur) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 5
# Need 644 more images (fetching 1288 URLs).
# Removed 42 corrupt images.
# [i] Kantajew Temple (Dinajpur): now 489/1050 images.
#
# === Kantajew Temple (Dinajpur) (Architecture) | Attempt 7 ===
# Query: Kantajew Temple (Dinajpur) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 6
# Need 561 more images (fetching 1122 URLs).
# Removed 42 corrupt images.
# [i] Kantajew Temple (Dinajpur): now 573/1050 images.
#
# === Kantajew Temple (Dinajpur) (Architecture) | Attempt 8 ===
# Query: Kantajew Temple (Dinajpur) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 7
# Need 477 more images (fetching 954 URLs).
# Removed 42 corrupt images.
# [i] Kantajew Temple (Dinajpur): now 654/1050 images.
#
# === Kantajew Temple (Dinajpur) (Architecture) | Attempt 9 ===
# Query: Kantajew Temple (Dinajpur) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 8
# Need 396 more images (fetching 792 URLs).
# Removed 42 corrupt images.
# [i] Kantajew Temple (Dinajpur): now 738/1050 images.
#
# === Kantajew Temple (Dinajpur) (Architecture) | Attempt 10 ===
# Query: Kantajew Temple (Dinajpur) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 9
# Need 312 more images (fetching 624 URLs).
# Removed 42 corrupt images.
# [i] Kantajew Temple (Dinajpur): now 822/1050 images.
#
# === Kantajew Temple (Dinajpur) (Architecture) | Attempt 11 ===
# Query: Kantajew Temple (Dinajpur) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 10
# Need 228 more images (fetching 456 URLs).
# Removed 42 corrupt images.
# [i] Kantajew Temple (Dinajpur): now 900/1050 images.
#
# === Kantajew Temple (Dinajpur) (Architecture) | Attempt 12 ===
# Query: Kantajew Temple (Dinajpur) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 11
# Need 150 more images (fetching 300 URLs).
# Removed 42 corrupt images.
# [i] Kantajew Temple (Dinajpur): now 981/1050 images.
#
# === Kantajew Temple (Dinajpur) (Architecture) | Attempt 13 ===
# Query: Kantajew Temple (Dinajpur) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 12
# Need 69 more images (fetching 138 URLs).
# Removed 42 corrupt images.
# [i] Kantajew Temple (Dinajpur): now 1061/1050 images.
# [✓] Kantajew Temple (Dinajpur): reached 1061/1050 images.
#
# === Panam Nagar (Sonargaon, Narayanganj) (Architecture) | Attempt 1 ===
# Query: Panam Nagar (Sonargaon, Narayanganj) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding
# Need 1050 more images (fetching 2100 URLs).
# Removed 52 corrupt images.
# [i] Panam Nagar (Sonargaon, Narayanganj): now 94/1050 images.
#
# === Panam Nagar (Sonargaon, Narayanganj) (Architecture) | Attempt 2 ===
# Query: Panam Nagar (Sonargaon, Narayanganj) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 1
# Need 956 more images (fetching 1912 URLs).
# Removed 52 corrupt images.
# [i] Panam Nagar (Sonargaon, Narayanganj): now 186/1050 images.
#
# === Panam Nagar (Sonargaon, Narayanganj) (Architecture) | Attempt 3 ===
# Query: Panam Nagar (Sonargaon, Narayanganj) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 2
# Need 864 more images (fetching 1728 URLs).
# Removed 52 corrupt images.
# [i] Panam Nagar (Sonargaon, Narayanganj): now 278/1050 images.
#
# === Panam Nagar (Sonargaon, Narayanganj) (Architecture) | Attempt 4 ===
# Query: Panam Nagar (Sonargaon, Narayanganj) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 3
# Need 772 more images (fetching 1544 URLs).
# Removed 52 corrupt images.
# [i] Panam Nagar (Sonargaon, Narayanganj): now 372/1050 images.
#
# === Panam Nagar (Sonargaon, Narayanganj) (Architecture) | Attempt 5 ===
# Query: Panam Nagar (Sonargaon, Narayanganj) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 4
# Need 678 more images (fetching 1356 URLs).
# Removed 52 corrupt images.
# [i] Panam Nagar (Sonargaon, Narayanganj): now 463/1050 images.
#
# === Panam Nagar (Sonargaon, Narayanganj) (Architecture) | Attempt 6 ===
# Query: Panam Nagar (Sonargaon, Narayanganj) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 5
# Need 587 more images (fetching 1174 URLs).
# Removed 52 corrupt images.
# [i] Panam Nagar (Sonargaon, Narayanganj): now 555/1050 images.
#
# === Panam Nagar (Sonargaon, Narayanganj) (Architecture) | Attempt 7 ===
# Query: Panam Nagar (Sonargaon, Narayanganj) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 6
# Need 495 more images (fetching 990 URLs).
# Removed 52 corrupt images.
# [i] Panam Nagar (Sonargaon, Narayanganj): now 647/1050 images.
#
# === Panam Nagar (Sonargaon, Narayanganj) (Architecture) | Attempt 8 ===
# Query: Panam Nagar (Sonargaon, Narayanganj) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 7
# Need 403 more images (fetching 806 URLs).
# Removed 52 corrupt images.
# [i] Panam Nagar (Sonargaon, Narayanganj): now 738/1050 images.
#
# === Panam Nagar (Sonargaon, Narayanganj) (Architecture) | Attempt 9 ===
# Query: Panam Nagar (Sonargaon, Narayanganj) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 8
# Need 312 more images (fetching 624 URLs).
# Removed 52 corrupt images.
# [i] Panam Nagar (Sonargaon, Narayanganj): now 831/1050 images.
#
# === Panam Nagar (Sonargaon, Narayanganj) (Architecture) | Attempt 10 ===
# Query: Panam Nagar (Sonargaon, Narayanganj) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 9
# Need 219 more images (fetching 438 URLs).
# Removed 52 corrupt images.
# [i] Panam Nagar (Sonargaon, Narayanganj): now 924/1050 images.
#
# === Panam Nagar (Sonargaon, Narayanganj) (Architecture) | Attempt 11 ===
# Query: Panam Nagar (Sonargaon, Narayanganj) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 10
# Need 126 more images (fetching 252 URLs).
# Removed 52 corrupt images.
# [i] Panam Nagar (Sonargaon, Narayanganj): now 1016/1050 images.
#
# === Panam Nagar (Sonargaon, Narayanganj) (Architecture) | Attempt 12 ===
# Query: Panam Nagar (Sonargaon, Narayanganj) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 11
# Need 34 more images (fetching 68 URLs).
# Removed 52 corrupt images.
# [i] Panam Nagar (Sonargaon, Narayanganj): now 1081/1050 images.
# [✓] Panam Nagar (Sonargaon, Narayanganj): reached 1081/1050 images.
#
# === Tajhat Palace (Rangpur) (Architecture) | Attempt 1 ===
# Query: Tajhat Palace (Rangpur) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding
# Need 1050 more images (fetching 2100 URLs).
# Removed 39 corrupt images.
# [i] Tajhat Palace (Rangpur): now 80/1050 images.
#
# === Tajhat Palace (Rangpur) (Architecture) | Attempt 2 ===
# Query: Tajhat Palace (Rangpur) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 1
# Need 970 more images (fetching 1940 URLs).
# Removed 39 corrupt images.
# [i] Tajhat Palace (Rangpur): now 159/1050 images.
#
# === Tajhat Palace (Rangpur) (Architecture) | Attempt 3 ===
# Query: Tajhat Palace (Rangpur) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 2
# Need 891 more images (fetching 1782 URLs).
# Removed 39 corrupt images.
# [i] Tajhat Palace (Rangpur): now 239/1050 images.
#
# === Tajhat Palace (Rangpur) (Architecture) | Attempt 4 ===
# Query: Tajhat Palace (Rangpur) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 3
# Need 811 more images (fetching 1622 URLs).
# Removed 39 corrupt images.
# [i] Tajhat Palace (Rangpur): now 318/1050 images.
#
# === Tajhat Palace (Rangpur) (Architecture) | Attempt 5 ===
# Query: Tajhat Palace (Rangpur) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 4
# Need 732 more images (fetching 1464 URLs).
# Removed 39 corrupt images.
# [i] Tajhat Palace (Rangpur): now 398/1050 images.
#
# === Tajhat Palace (Rangpur) (Architecture) | Attempt 6 ===
# Query: Tajhat Palace (Rangpur) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 5
# Need 652 more images (fetching 1304 URLs).
# Removed 39 corrupt images.
# [i] Tajhat Palace (Rangpur): now 477/1050 images.
#
# === Tajhat Palace (Rangpur) (Architecture) | Attempt 7 ===
# Query: Tajhat Palace (Rangpur) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 6
# Need 573 more images (fetching 1146 URLs).
# Removed 39 corrupt images.
# [i] Tajhat Palace (Rangpur): now 558/1050 images.
#
# === Tajhat Palace (Rangpur) (Architecture) | Attempt 8 ===
# Query: Tajhat Palace (Rangpur) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 7
# Need 492 more images (fetching 984 URLs).
# Removed 39 corrupt images.
# [i] Tajhat Palace (Rangpur): now 638/1050 images.
#
# === Tajhat Palace (Rangpur) (Architecture) | Attempt 9 ===
# Query: Tajhat Palace (Rangpur) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 8
# Need 412 more images (fetching 824 URLs).
# Removed 39 corrupt images.
# [i] Tajhat Palace (Rangpur): now 718/1050 images.
#
# === Tajhat Palace (Rangpur) (Architecture) | Attempt 10 ===
# Query: Tajhat Palace (Rangpur) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 9
# Need 332 more images (fetching 664 URLs).
# Removed 39 corrupt images.
# [i] Tajhat Palace (Rangpur): now 799/1050 images.
#
# === Tajhat Palace (Rangpur) (Architecture) | Attempt 11 ===
# Query: Tajhat Palace (Rangpur) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 10
# Need 251 more images (fetching 502 URLs).
# Removed 39 corrupt images.
# [i] Tajhat Palace (Rangpur): now 878/1050 images.
#
# === Tajhat Palace (Rangpur) (Architecture) | Attempt 12 ===
# Query: Tajhat Palace (Rangpur) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 11
# Need 172 more images (fetching 344 URLs).
# Removed 39 corrupt images.
# [i] Tajhat Palace (Rangpur): now 958/1050 images.
#
# === Tajhat Palace (Rangpur) (Architecture) | Attempt 13 ===
# Query: Tajhat Palace (Rangpur) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 12
# Need 92 more images (fetching 184 URLs).
# Removed 39 corrupt images.
# [i] Tajhat Palace (Rangpur): now 1037/1050 images.
#
# === Tajhat Palace (Rangpur) (Architecture) | Attempt 14 ===
# Query: Tajhat Palace (Rangpur) exterior architecture building monument facade heritage -interior -floorplan -selfie -people -crowd -tourist -group -human -face -portrait -wedding photo view picture 13
# Need 13 more images (fetching 26 URLs).
# Removed 39 corrupt images.
# [i] Tajhat Palace (Rangpur): now 1057/1050 images.
# [✓] Tajhat Palace (Rangpur): reached 1057/1050 images.
#
# === Cox’s Bazar Sea Beach (Cox’s Bazar) (Nature) | Attempt 1 ===
# Query: Cox’s Bazar Sea Beach (Cox’s Bazar) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait
# Need 1050 more images (fetching 2100 URLs).
# Removed 49 corrupt images.
# [i] Cox’s Bazar Sea Beach (Cox’s Bazar): now 92/1050 images.
#
# === Cox’s Bazar Sea Beach (Cox’s Bazar) (Nature) | Attempt 2 ===
# Query: Cox’s Bazar Sea Beach (Cox’s Bazar) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 1
# Need 958 more images (fetching 1916 URLs).
# Removed 49 corrupt images.
# [i] Cox’s Bazar Sea Beach (Cox’s Bazar): now 185/1050 images.
#
# === Cox’s Bazar Sea Beach (Cox’s Bazar) (Nature) | Attempt 3 ===
# Query: Cox’s Bazar Sea Beach (Cox’s Bazar) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 2
# Need 865 more images (fetching 1730 URLs).
# Removed 49 corrupt images.
# [i] Cox’s Bazar Sea Beach (Cox’s Bazar): now 279/1050 images.
#
# === Cox’s Bazar Sea Beach (Cox’s Bazar) (Nature) | Attempt 4 ===
# Query: Cox’s Bazar Sea Beach (Cox’s Bazar) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 3
# Need 771 more images (fetching 1542 URLs).
# Removed 49 corrupt images.
# [i] Cox’s Bazar Sea Beach (Cox’s Bazar): now 373/1050 images.
#
# === Cox’s Bazar Sea Beach (Cox’s Bazar) (Nature) | Attempt 5 ===
# Query: Cox’s Bazar Sea Beach (Cox’s Bazar) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 4
# Need 677 more images (fetching 1354 URLs).
# Removed 49 corrupt images.
# [i] Cox’s Bazar Sea Beach (Cox’s Bazar): now 467/1050 images.
#
# === Cox’s Bazar Sea Beach (Cox’s Bazar) (Nature) | Attempt 6 ===
# Query: Cox’s Bazar Sea Beach (Cox’s Bazar) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 5
# Need 583 more images (fetching 1166 URLs).
# Removed 49 corrupt images.
# [i] Cox’s Bazar Sea Beach (Cox’s Bazar): now 561/1050 images.
#
# === Cox’s Bazar Sea Beach (Cox’s Bazar) (Nature) | Attempt 7 ===
# Query: Cox’s Bazar Sea Beach (Cox’s Bazar) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 6
# Need 489 more images (fetching 978 URLs).
# Removed 49 corrupt images.
# [i] Cox’s Bazar Sea Beach (Cox’s Bazar): now 654/1050 images.
#
# === Cox’s Bazar Sea Beach (Cox’s Bazar) (Nature) | Attempt 8 ===
# ...
# Need 593 more images (fetching 1186 URLs).
# Removed 32 corrupt images.
# [i] Jaflong (Sylhet): now 550/1050 images.
#
# === Jaflong (Sylhet) (Nature) | Attempt 7 ===
# Query: Jaflong (Sylhet) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 6
# Need 500 more images (fetching 1000 URLs).
# Removed 32 corrupt images.
# [i] Jaflong (Sylhet): now 643/1050 images.
#
# === Jaflong (Sylhet) (Nature) | Attempt 8 ===
# Query: Jaflong (Sylhet) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 7
# Need 407 more images (fetching 814 URLs).
# Removed 32 corrupt images.
# [i] Jaflong (Sylhet): now 735/1050 images.
#
# === Jaflong (Sylhet) (Nature) | Attempt 9 ===
# Query: Jaflong (Sylhet) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 8
# Need 315 more images (fetching 630 URLs).
# Removed 32 corrupt images.
# [i] Jaflong (Sylhet): now 826/1050 images.
#
# === Jaflong (Sylhet) (Nature) | Attempt 10 ===
# Query: Jaflong (Sylhet) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 9
# Need 224 more images (fetching 448 URLs).
# Removed 32 corrupt images.
# [i] Jaflong (Sylhet): now 918/1050 images.
#
# === Jaflong (Sylhet) (Nature) | Attempt 11 ===
# Query: Jaflong (Sylhet) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 10
# Need 132 more images (fetching 264 URLs).
# Removed 32 corrupt images.
# [i] Jaflong (Sylhet): now 1008/1050 images.
#
# === Jaflong (Sylhet) (Nature) | Attempt 12 ===
# Query: Jaflong (Sylhet) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 11
# Need 42 more images (fetching 84 URLs).
# Removed 32 corrupt images.
# [i] Jaflong (Sylhet): now 1085/1050 images.
# [✓] Jaflong (Sylhet): reached 1085/1050 images.
#
# === Ratargul Swamp Forest (Sylhet) (Nature) | Attempt 1 ===
# Query: Ratargul Swamp Forest (Sylhet) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait
# Need 1050 more images (fetching 2100 URLs).
# Removed 46 corrupt images.
# [i] Ratargul Swamp Forest (Sylhet): now 95/1050 images.
#
# === Ratargul Swamp Forest (Sylhet) (Nature) | Attempt 2 ===
# Query: Ratargul Swamp Forest (Sylhet) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 1
# Need 955 more images (fetching 1910 URLs).
# Removed 46 corrupt images.
# [i] Ratargul Swamp Forest (Sylhet): now 188/1050 images.
#
# === Ratargul Swamp Forest (Sylhet) (Nature) | Attempt 3 ===
# Query: Ratargul Swamp Forest (Sylhet) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 2
# Need 862 more images (fetching 1724 URLs).
# Removed 46 corrupt images.
# [i] Ratargul Swamp Forest (Sylhet): now 283/1050 images.
#
# === Ratargul Swamp Forest (Sylhet) (Nature) | Attempt 4 ===
# Query: Ratargul Swamp Forest (Sylhet) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 3
# Need 767 more images (fetching 1534 URLs).
# Removed 46 corrupt images.
# [i] Ratargul Swamp Forest (Sylhet): now 378/1050 images.
#
# === Ratargul Swamp Forest (Sylhet) (Nature) | Attempt 5 ===
# Query: Ratargul Swamp Forest (Sylhet) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 4
# Need 672 more images (fetching 1344 URLs).
# Removed 46 corrupt images.
# [i] Ratargul Swamp Forest (Sylhet): now 473/1050 images.
#
# === Ratargul Swamp Forest (Sylhet) (Nature) | Attempt 6 ===
# Query: Ratargul Swamp Forest (Sylhet) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 5
# Need 577 more images (fetching 1154 URLs).
# Removed 46 corrupt images.
# [i] Ratargul Swamp Forest (Sylhet): now 568/1050 images.
#
# === Ratargul Swamp Forest (Sylhet) (Nature) | Attempt 7 ===
# Query: Ratargul Swamp Forest (Sylhet) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 6
# Need 482 more images (fetching 964 URLs).
# Removed 46 corrupt images.
# [i] Ratargul Swamp Forest (Sylhet): now 663/1050 images.
#
# === Ratargul Swamp Forest (Sylhet) (Nature) | Attempt 8 ===
# Query: Ratargul Swamp Forest (Sylhet) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 7
# Need 387 more images (fetching 774 URLs).
# Removed 46 corrupt images.
# [i] Ratargul Swamp Forest (Sylhet): now 758/1050 images.
#
# === Ratargul Swamp Forest (Sylhet) (Nature) | Attempt 9 ===
# Query: Ratargul Swamp Forest (Sylhet) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 8
# Need 292 more images (fetching 584 URLs).
# Removed 46 corrupt images.
# [i] Ratargul Swamp Forest (Sylhet): now 852/1050 images.
#
# === Ratargul Swamp Forest (Sylhet) (Nature) | Attempt 10 ===
# Query: Ratargul Swamp Forest (Sylhet) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 9
# Need 198 more images (fetching 396 URLs).
# Removed 46 corrupt images.
# [i] Ratargul Swamp Forest (Sylhet): now 947/1050 images.
#
# === Ratargul Swamp Forest (Sylhet) (Nature) | Attempt 11 ===
# Query: Ratargul Swamp Forest (Sylhet) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 10
# Need 103 more images (fetching 206 URLs).
# Removed 46 corrupt images.
# [i] Ratargul Swamp Forest (Sylhet): now 1041/1050 images.
#
# === Ratargul Swamp Forest (Sylhet) (Nature) | Attempt 12 ===
# Query: Ratargul Swamp Forest (Sylhet) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 11
# Need 9 more images (fetching 18 URLs).
# Removed 46 corrupt images.
# [i] Ratargul Swamp Forest (Sylhet): now 1058/1050 images.
# [✓] Ratargul Swamp Forest (Sylhet): reached 1058/1050 images.
#
# === Sajek Valley (Rangamati) (Nature) | Attempt 1 ===
# Query: Sajek Valley (Rangamati) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait
# Need 1050 more images (fetching 2100 URLs).
# Removed 40 corrupt images.
# [i] Sajek Valley (Rangamati): now 87/1050 images.
#
# === Sajek Valley (Rangamati) (Nature) | Attempt 2 ===
# Query: Sajek Valley (Rangamati) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 1
# Need 963 more images (fetching 1926 URLs).
# Removed 40 corrupt images.
# [i] Sajek Valley (Rangamati): now 174/1050 images.
#
# === Sajek Valley (Rangamati) (Nature) | Attempt 3 ===
# Query: Sajek Valley (Rangamati) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 2
# Need 876 more images (fetching 1752 URLs).
# Removed 40 corrupt images.
# [i] Sajek Valley (Rangamati): now 260/1050 images.
#
# === Sajek Valley (Rangamati) (Nature) | Attempt 4 ===
# Query: Sajek Valley (Rangamati) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 3
# Need 790 more images (fetching 1580 URLs).
# Removed 40 corrupt images.
# [i] Sajek Valley (Rangamati): now 348/1050 images.
#
# === Sajek Valley (Rangamati) (Nature) | Attempt 5 ===
# Query: Sajek Valley (Rangamati) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 4
# Need 702 more images (fetching 1404 URLs).
# Removed 40 corrupt images.
# [i] Sajek Valley (Rangamati): now 436/1050 images.
#
# === Sajek Valley (Rangamati) (Nature) | Attempt 6 ===
# Query: Sajek Valley (Rangamati) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 5
# Need 614 more images (fetching 1228 URLs).
# Removed 40 corrupt images.
# [i] Sajek Valley (Rangamati): now 523/1050 images.
#
# === Sajek Valley (Rangamati) (Nature) | Attempt 7 ===
# Query: Sajek Valley (Rangamati) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 6
# Need 527 more images (fetching 1054 URLs).
# Removed 40 corrupt images.
# [i] Sajek Valley (Rangamati): now 612/1050 images.
#
# === Sajek Valley (Rangamati) (Nature) | Attempt 8 ===
# Query: Sajek Valley (Rangamati) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 7
# Need 438 more images (fetching 876 URLs).
# Removed 40 corrupt images.
# [i] Sajek Valley (Rangamati): now 700/1050 images.
#
# === Sajek Valley (Rangamati) (Nature) | Attempt 9 ===
# Query: Sajek Valley (Rangamati) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 8
# Need 350 more images (fetching 700 URLs).
# Removed 40 corrupt images.
# [i] Sajek Valley (Rangamati): now 787/1050 images.
#
# === Sajek Valley (Rangamati) (Nature) | Attempt 10 ===
# Query: Sajek Valley (Rangamati) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 9
# Need 263 more images (fetching 526 URLs).
# Removed 40 corrupt images.
# [i] Sajek Valley (Rangamati): now 876/1050 images.
#
# === Sajek Valley (Rangamati) (Nature) | Attempt 11 ===
# Query: Sajek Valley (Rangamati) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 10
# Need 174 more images (fetching 348 URLs).
# Removed 40 corrupt images.
# [i] Sajek Valley (Rangamati): now 964/1050 images.
#
# === Sajek Valley (Rangamati) (Nature) | Attempt 12 ===
# Query: Sajek Valley (Rangamati) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 11
# Need 86 more images (fetching 172 URLs).
# Removed 40 corrupt images.
# [i] Sajek Valley (Rangamati): now 1052/1050 images.
# [✓] Sajek Valley (Rangamati): reached 1052/1050 images.
#
# === Nafakhum Waterfall (Bandarban) (Nature) | Attempt 1 ===
# Query: Nafakhum Waterfall (Bandarban) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait
# Need 1050 more images (fetching 2100 URLs).
# Removed 46 corrupt images.
# [i] Nafakhum Waterfall (Bandarban): now 94/1050 images.
#
# === Nafakhum Waterfall (Bandarban) (Nature) | Attempt 2 ===
# Query: Nafakhum Waterfall (Bandarban) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 1
# Need 956 more images (fetching 1912 URLs).
# Removed 46 corrupt images.
# [i] Nafakhum Waterfall (Bandarban): now 187/1050 images.
#
# === Nafakhum Waterfall (Bandarban) (Nature) | Attempt 3 ===
# Query: Nafakhum Waterfall (Bandarban) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 2
# Need 863 more images (fetching 1726 URLs).
# Removed 46 corrupt images.
# [i] Nafakhum Waterfall (Bandarban): now 281/1050 images.
#
# === Nafakhum Waterfall (Bandarban) (Nature) | Attempt 4 ===
# Query: Nafakhum Waterfall (Bandarban) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 3
# Need 769 more images (fetching 1538 URLs).
# Removed 46 corrupt images.
# [i] Nafakhum Waterfall (Bandarban): now 374/1050 images.
#
# === Nafakhum Waterfall (Bandarban) (Nature) | Attempt 5 ===
# Query: Nafakhum Waterfall (Bandarban) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 4
# Need 676 more images (fetching 1352 URLs).
# Removed 46 corrupt images.
# [i] Nafakhum Waterfall (Bandarban): now 468/1050 images.
#
# === Nafakhum Waterfall (Bandarban) (Nature) | Attempt 6 ===
# Query: Nafakhum Waterfall (Bandarban) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 5
# Need 582 more images (fetching 1164 URLs).
# Removed 46 corrupt images.
# [i] Nafakhum Waterfall (Bandarban): now 562/1050 images.
#
# === Nafakhum Waterfall (Bandarban) (Nature) | Attempt 7 ===
# Query: Nafakhum Waterfall (Bandarban) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 6
# Need 488 more images (fetching 976 URLs).
# Removed 46 corrupt images.
# [i] Nafakhum Waterfall (Bandarban): now 656/1050 images.
#
# === Nafakhum Waterfall (Bandarban) (Nature) | Attempt 8 ===
# Query: Nafakhum Waterfall (Bandarban) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 7
# Need 394 more images (fetching 788 URLs).
# Removed 46 corrupt images.
# [i] Nafakhum Waterfall (Bandarban): now 751/1050 images.
#
# === Nafakhum Waterfall (Bandarban) (Nature) | Attempt 9 ===
# Query: Nafakhum Waterfall (Bandarban) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 8
# Need 299 more images (fetching 598 URLs).
# Removed 46 corrupt images.
# [i] Nafakhum Waterfall (Bandarban): now 845/1050 images.
#
# === Nafakhum Waterfall (Bandarban) (Nature) | Attempt 10 ===
# Query: Nafakhum Waterfall (Bandarban) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 9
# Need 205 more images (fetching 410 URLs).
# Removed 46 corrupt images.
# [i] Nafakhum Waterfall (Bandarban): now 938/1050 images.
#
# === Nafakhum Waterfall (Bandarban) (Nature) | Attempt 11 ===
# Query: Nafakhum Waterfall (Bandarban) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 10
# Need 112 more images (fetching 224 URLs).
# Removed 46 corrupt images.
# [i] Nafakhum Waterfall (Bandarban): now 1032/1050 images.
#
# === Nafakhum Waterfall (Bandarban) (Nature) | Attempt 12 ===
# Query: Nafakhum Waterfall (Bandarban) landscape scenery nature hills forest river mountain valley beach waterfall -selfie -people -tourist -crowd -group -human -face -portrait photo view picture 11
# Need 18 more images (fetching 36 URLs).
# Removed 46 corrupt images.
# [i] Nafakhum Waterfall (Bandarban): now 1066/1050 images.
# [✓] Nafakhum Waterfall (Bandarban): reached 1066/1050 images.

# %%
from PIL import Image, UnidentifiedImageError
for img_path in DEST_ROOT.rglob("*"):
    if img_path.is_file() and not img_path.name.startswith("."):
        try:
            img = Image.open(img_path)
            img.verify()
        except (IOError, SyntaxError, UnidentifiedImageError):
            print(f"Removing corrupted image: {img_path}")
            img_path.unlink()  # delete corrupted image

# %%
import os

# Define the root directory of your dataset
dataset_root = DEST_ROOT # Use the variable defined earlier

# Get a list of all class directories
class_directories = [d for d in os.listdir(dataset_root) if os.path.isdir(os.path.join(dataset_root, d))]

# Count the images in each directory
class_counts = {}
for class_dir in class_directories:
    dir_path = os.path.join(dataset_root, class_dir)
    image_count = ensure_target_count(Path(dir_path)) # Reuse the function ensure_target_count
    class_counts[class_dir] = image_count

# Display the counts
print("Image counts per class:")
for class_name, count in class_counts.items():
    print(f"- {class_name}: {count}")

# Optional: Display total count
total_images = sum(class_counts.values())
print(f"\nTotal images in the dataset: {total_images}")
# Out:
# Image counts per class:
# - Jatiya Sangsad Bhaban (Dhaka): 1079
# - Ahsan Manzil (Dhaka): 1082
# - Lalbagh Fort (Dhaka): 1064
# - Dhaka Shaheed Minar (Bangladesh): 1069
# - Sixty Dome Mosque (Bagerhat): 1079
# - Somapura Mahavihara (Paharpur, Naogaon): 1050
# - Kantajew Temple (Dinajpur): 1054
# - Panam Nagar (Sonargaon, Narayanganj): 1081
# - Tajhat Palace (Rangpur): 1050
# - Coxs Bazar Sea Beach (Coxs Bazar): 1058
# - St. Martin's Island (Teknaf, Chhera Dwip): 1050
# - Sundarbans Mangrove Forest (Khulna)e: 1086
# - Jaflong (Sylhet): 1085
# - Ratargul Swamp Forest (Sylhet): 1058
# - Sajek Valley (Rangamati): 1052
# - Nafakhum Waterfall (Bandarban): 1055
#
# Total images in the dataset: 17052

# %%
import os
import random

# Find classes that have more than the target
classes_to_trim = [(name, count - TARGET_PER_CLASS) for name, count in class_counts.items() if count > TARGET_PER_CLASS]

print("Classes needing images removed:")
for name, excess in classes_to_trim:
    print(f"- {name}: Has {excess} excess images.")

# Remove excess images from the over-target classes
for place_name, excess in classes_to_trim:
    class_dir = DEST_ROOT / sanitize_dirname(place_name)
    image_files = [p for p in class_dir.glob("*") if p.suffix.lower() in {".jpg", ".jpeg", ".png", ".bmp", ".gif", ".webp"} and not p.name.startswith(".")]

    # Randomly select excess images to remove
    images_to_remove = random.sample(image_files, excess)

    print(f"\n=== Trimming {place_name} ===")
    print(f"Removing {len(images_to_remove)} images.")

    for img_path in images_to_remove:
        try:
            img_path.unlink()
        except OSError as e:
            print(f"Error removing image {img_path}: {e}")

    final_count = ensure_target_count(class_dir)
    print(f"[i] {place_name}: now {final_count}/{TARGET_PER_CLASS} images.")
# Out:
# Classes needing images removed:
# - Jatiya Sangsad Bhaban (Dhaka): Has 29 excess images.
# - Ahsan Manzil (Dhaka): Has 32 excess images.
# - Lalbagh Fort (Dhaka): Has 14 excess images.
# - Dhaka Shaheed Minar (Bangladesh): Has 19 excess images.
# - Sixty Dome Mosque (Bagerhat): Has 29 excess images.
# - Kantajew Temple (Dinajpur): Has 4 excess images.
# - Panam Nagar (Sonargaon, Narayanganj): Has 31 excess images.
# - Coxs Bazar Sea Beach (Coxs Bazar): Has 8 excess images.
# - Sundarbans Mangrove Forest (Khulna)e: Has 36 excess images.
# - Jaflong (Sylhet): Has 35 excess images.
# - Ratargul Swamp Forest (Sylhet): Has 8 excess images.
# - Sajek Valley (Rangamati): Has 2 excess images.
# - Nafakhum Waterfall (Bandarban): Has 5 excess images.
#
# === Trimming Jatiya Sangsad Bhaban (Dhaka) ===
# Removing 29 images.
# [i] Jatiya Sangsad Bhaban (Dhaka): now 1050/1050 images.
#
# === Trimming Ahsan Manzil (Dhaka) ===
# Removing 32 images.
# [i] Ahsan Manzil (Dhaka): now 1050/1050 images.
#
# === Trimming Lalbagh Fort (Dhaka) ===
# Removing 14 images.
# [i] Lalbagh Fort (Dhaka): now 1050/1050 images.
#
# === Trimming Dhaka Shaheed Minar (Bangladesh) ===
# Removing 19 images.
# [i] Dhaka Shaheed Minar (Bangladesh): now 1050/1050 images.
#
# === Trimming Sixty Dome Mosque (Bagerhat) ===
# Removing 29 images.
# [i] Sixty Dome Mosque (Bagerhat): now 1050/1050 images.
#
# === Trimming Kantajew Temple (Dinajpur) ===
# Removing 4 images.
# [i] Kantajew Temple (Dinajpur): now 1050/1050 images.
#
# === Trimming Panam Nagar (Sonargaon, Narayanganj) ===
# Removing 31 images.
# [i] Panam Nagar (Sonargaon, Narayanganj): now 1050/1050 images.
#
# === Trimming Coxs Bazar Sea Beach (Coxs Bazar) ===
# Removing 8 images.
# [i] Coxs Bazar Sea Beach (Coxs Bazar): now 1050/1050 images.
#
# === Trimming Sundarbans Mangrove Forest (Khulna)e ===
# Removing 36 images.
# [i] Sundarbans Mangrove Forest (Khulna)e: now 1050/1050 images.
#
# === Trimming Jaflong (Sylhet) ===
# Removing 35 images.
# [i] Jaflong (Sylhet): now 1050/1050 images.
#
# === Trimming Ratargul Swamp Forest (Sylhet) ===
# Removing 8 images.
# [i] Ratargul Swamp Forest (Sylhet): now 1050/1050 images.
#
# === Trimming Sajek Valley (Rangamati) ===
# Removing 2 images.
# [i] Sajek Valley (Rangamati): now 1050/1050 images.
#
# === Trimming Nafakhum Waterfall (Bandarban) ===
# Removing 5 images.
# [i] Nafakhum Waterfall (Bandarban): now 1050/1050 images.

# %%
import os

# Define the root directory of your dataset
dataset_root = DEST_ROOT # Use the variable defined earlier

# Get a list of all class directories
class_directories = [d for d in os.listdir(dataset_root) if os.path.isdir(os.path.join(dataset_root, d))]

# Count the images in each directory
class_counts = {}
for class_dir in class_directories:
    dir_path = os.path.join(dataset_root, class_dir)
    image_count = ensure_target_count(Path(dir_path)) # Reuse the function ensure_target_count
    class_counts[class_dir] = image_count

# Display the counts
print("Image counts per class:")
for class_name, count in class_counts.items():
    print(f"- {class_name}: {count}")

# Optional: Display total count
total_images = sum(class_counts.values())
print(f"\nTotal images in the dataset: {total_images}")
# Out:
# Image counts per class:
# - Jatiya Sangsad Bhaban : 1050
# - Ahsan Manzil : 1050
# - Lalbagh Fort : 1050
# - Dhaka Shaheed Minar : 1050
# - Sixty Dome Mosque : 1050
# - Somapura Mahavihara : 1050
# - Kantajew Temple : 1050
# - Panam Nagar : 1050
# - Tajhat Palace : 1050
# - Coxs Bazar Sea Beach : 1050
# - St. Martin's Island : 1050
# - Sundarbans Mangrove Forest : 1050
# - Jaflong : 1050
# - Ratargul Swamp Forest : 1050
# - Sajek Valley : 1050
# - Nafakhum Waterfall : 1050
#
# Total images in the dataset: 16800
